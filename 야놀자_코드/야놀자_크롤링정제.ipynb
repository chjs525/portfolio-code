# %% [markdown]
# # 야놀자 주중판매가 정제
# ## 정제는 1~10 순서대로 내려감
# - df_주중: 주중판매가 크롤링 데이터
# - df_메인: 야놀자에서 제공한 데이터

# %%
import pandas as pd

df_주중 = pd.read_csv('야놀자_크롤링/숙소정보.csv')
df_메인 = pd.read_csv('0731_메인프레임.v3.csv')

# %%
df_메인.head()
# Out:
#    LDGS_CD          LDGS_NM  LDGS_TY_CD LDGMNT_TY_NM  LDGS_ZIP_NO  \
# 0    23184  영등포라이프스타일FHOTEL           1        Motel         7306
# 1    23192           청주오창M+           1        Motel        28118
# 2    23197             강남렉시           1        Motel         6235
# 3    23204         대전유성시나브로           1        Motel        34185
# 4    23206    부천(상동)MYHOTEL           1        Motel        14542
#
#              LDGS_ROAD_NM_ADDR    LDGS_LA     LDGS_LO CHIN_TIME CHOT_TIME  \
# 0   서울 영등포구 경인로108길 8 (영등포동1가)  37.517182  126.911217     23:00     12:00
# 1  충청북도 청주시 청원구 오창읍 양청송대길 9-12  36.713884  127.439228     18:00     12:00
# 2         서울특별시 강남구 테헤란로16길 11  37.498792  127.033956     23:00     13:00
# 3         대전광역시 유성구 온천북로59번길 9  36.356873  127.349172     17:00     13:00
# 4   경기도 부천시 길주로121번길 18-11(상동)  37.506612  126.756644       NaN       NaN
#
#   숙소 검색량(전체) 상위 시도 하위 시구   지역별_관심도  유튜브_상위20_평균조회수
# 0         20    서울  영등포구  3.057270          725000
# 1         20    충북   청주시  2.802088           67961
# 2        310    서울   강남구  3.057270          725000
# 3         20    대전   유성구  2.918471          155050
# 4         20    경기   부천시  2.928911          246000

# %% [markdown]
# - 'LDGS_CD' -> '숙소ID' (숙소명 변경)

# %%
# df_메인 LDGS_CD 컬럼 명 변경
df_메인.rename(columns={'LDGS_CD': '숙소ID'}, inplace=True)

# %%
df_주중
# Out:
#              숙소ID   별점    리뷰수   주중판매가
# 0           23184  4.7  3,202   65000
# 1           23192  4.6    670    예약마감
# 2           23197  4.2  9,275   60000
# 3           23204  4.7    245   60000
# 4           23206   후기     없음    예약마감
# ...           ...  ...    ...     ...
# 26978  1000114540   후기     없음  110000
# 26979  1000114543   후기     없음    예약마감
# 26980  1000114558  2.7     38   60000
# 26981  1000114577  4.9    456   70000
# 26982  1000114675  4.9  1,168   55000
#
# [26983 rows x 4 columns]

# %% [markdown]
# - df_메인에는 있고 df_nol에는 없는 상품ID(숙소ID)

# %%
# df_메인에는 있고 df_nol에는 없는 상품ID(숙소ID) 확인 및 행 출력
missing_ids = set(df_메인['숙소ID']) - set(df_주중['숙소ID'])
df_누락 = df_메인[df_메인['숙소ID'].isin(missing_ids)]

# %% [markdown]
# - df_주중 : 야놀자 크롤링 돌린데이터에 별점, 리뷰수, 주중판매가 오류인 숙소 재크롤링
# - df_누락1 변수로 분리

# %%
# 별점 컬럼이 후기이거나 nan 경우, 리뷰수가 없음인 경우, 주중판매가가 예약마감이나 없음인 경우인 행 출력
df_누락1 = df_주중[
    (df_주중['별점'] == '후기') | 
    (df_주중['별점'].isna()) | 
    (df_주중['리뷰수'] == '없음') | 
    (df_주중['주중판매가'] == '예약마감') | 
    (df_주중['주중판매가'] == '없음')
]
df_누락1
# Out:
#              숙소ID   별점    리뷰수   주중판매가
# 1           23192  4.6    670    예약마감
# 4           23206   후기     없음    예약마감
# 20          23245  4.7  4,336    예약마감
# 22          23271  4.9  3,213    예약마감
# 29          23291  4.6    820    예약마감
# ...           ...  ...    ...     ...
# 26969  1000114487  NaN     없음    예약마감
# 26970  1000114491  4.6    264    예약마감
# 26971  1000114500  4.3     27    예약마감
# 26978  1000114540   후기     없음  110000
# 26979  1000114543   후기     없음    예약마감
#
# [9603 rows x 4 columns]

# %% [markdown]
# - df_주중_clean : 오류가 없는 행 분리

# %%
# 별점 컬럼이 후기이거나 nan 경우, 리뷰수가 없음인 경우, 주중판매가가 예약마감이나 없음인 경우인 행 삭제
df_주중_clean = df_주중[
    ~(
        (df_주중['별점'] == '후기') | 
        (df_주중['별점'].isna()) | 
        (df_주중['리뷰수'] == '없음') | 
        (df_주중['주중판매가'] == '예약마감') | 
        (df_주중['주중판매가'] == '없음')
    )
]
df_주중_clean
# Out:
#              숙소ID   별점     리뷰수       주중판매가
# 0           23184  4.7   3,202       65000
# 2           23197  4.2   9,275       60000
# 3           23204  4.7     245       60000
# 5           23207  4.8  10,124  최대할인가55000
# 6           23216  4.6   4,501       45000
# ...           ...  ...     ...         ...
# 26976  1000114526  3.3      64       45000
# 26977  1000114529  4.3      51      115000
# 26980  1000114558  2.7      38       60000
# 26981  1000114577  4.9     456       70000
# 26982  1000114675  4.9   1,168       55000
#
# [17380 rows x 4 columns]

# %% [markdown]
# - 메인프레임에만 있는 숙소ID와 누락 값이 있는 df_누락1과 concat

# %%
# df_누락['상품ID'] 와 df_누락1['숙소ID'] 합치기
combined_ids = pd.concat([df_누락['숙소ID'], df_누락1['숙소ID']]).drop_duplicates().reset_index(drop=True)
combined_ids
# Out:
# 0         10054075
# 1         10059010
# 2         10059501
# 3         10059525
# 4         10059594
#            ...
# 9623    1000114487
# 9624    1000114491
# 9625    1000114500
# 9626    1000114540
# 9627    1000114543
# Name: 숙소ID, Length: 9628, dtype: int64

# %% [markdown]
# - combined_ids 데이터프레임으로 변환

# %%
# combined_ids 데이터프레임으로 변환
df_combined_ids = pd.DataFrame(combined_ids, columns=['숙소ID'])
df_combined_ids
# Out:
#             숙소ID
# 0       10054075
# 1       10059010
# 2       10059501
# 3       10059525
# 4       10059594
# ...          ...
# 9623  1000114487
# 9624  1000114491
# 9625  1000114500
# 9626  1000114540
# 9627  1000114543
#
# [9628 rows x 1 columns]

# %% [markdown]
# ## 2차 정제
# - 크롤링 돌린 데이터 로드

# %%
df_누락수정 =  pd.read_csv('야놀자_크롤링/누락숙소.csv')
df_누락수정1 =  pd.read_csv('야놀자_크롤링/1차누락숙소.csv')

# %% [markdown]
# - 데이터 병합

# %%
# df_누락수정와 df_누락수정1 concat
df_누락수정_combined = pd.concat([df_누락수정, df_누락수정1], ignore_index=True)

# %% [markdown]
# - 숙소ID 중복인행 출력

# %%
# 숙소ID 기준으로 중복인 행 출력
df_누락수정_combined[df_누락수정_combined.duplicated(subset=['숙소ID'], keep=False)].sort_values(by='숙소ID', ascending=False).head()
# Out:
#             숙소ID   별점    리뷰수 주중판매가
# 9657  1000111408  5.0     30  예약마감
# 9628  1000111408  5.0     30  예약마감
# 9627  1000111194  4.6  4,271  예약마감
# 9656  1000111194  4.6  4,271  예약마감
# 9655  1000111061  NaN     없음    없음

# %%
# 숙소ID 기준으로 중복된 행을 하나만 남기고 삭제
# (keep='first'로 첫 번째만 남김)
df_누락수정_combined = df_누락수정_combined.drop_duplicates(subset=['숙소ID'], keep='first')
df_누락수정_combined
# Out:
#             숙소ID   별점    리뷰수   주중판매가
# 0       10054075  NaN     없음    예약마감
# 1       10059010  5.0      2  280000
# 2       10059501  4.0     13    예약마감
# 3       10059525  5.0      2  780000
# 4       10059594  3.0      2  700000
# ...          ...  ...    ...     ...
# 9624  1000110527   후기     없음  219000
# 9625  1000110771  4.8    201    예약마감
# 9626  1000111061  NaN     없음      없음
# 9627  1000111194  4.6  4,271    예약마감
# 9628  1000111408  5.0     30    예약마감
#
# [9628 rows x 4 columns]

# %% [markdown]
# - df_누락수정_combined : 예약마감 및 없음인 행은 삭제

# %%
# df_누락수정_combined 주중판매가 컬럼이 '예약마감'및 없음 인 행 삭제
df_누락수정_combined = df_누락수정_combined[
    ~(
        (df_누락수정_combined['주중판매가'] == '예약마감') | 
        (df_누락수정_combined['주중판매가'] == '없음')
    )
]

# %%
# 주중판매가 컬럼이 '예약마감'인 행 출력
df_누락수정_크롤링 = df_누락수정_combined[df_누락수정_combined['주중판매가'] == '예약마감']

# %% [markdown]
# ## 3차 정제

# %% [markdown]
# ## 주중판매가 정제

# %%
df_2차누락숙소 = pd.read_csv('야놀자_크롤링/2차누락숙소.csv')

# %%
df_2차누락숙소
# Out:
#             숙소ID   별점    리뷰수   주중판매가
# 0       10054075   없음     없음  260000
# 1       10059501  4.0     13   40000
# 2       10059932  5.0      3   49000
# 3       10060452   없음     없음  400000
# 4       10060499  4.4     31   50000
# ...          ...  ...    ...     ...
# 3497  1000109477  2.0      1  250000
# 3498  1000109538   없음     37    예약마감
# 3499  1000110771  4.8    201   40000
# 3500  1000111194  4.6  4,271    예약마감
# 3501  1000111408  5.0     30  160000
#
# [3502 rows x 4 columns]

# %%
# df_주중_clean , df_누락수정_combined, df_2차누락숙소 contcat
df_주중최종 = pd.concat([df_주중_clean, df_누락수정_combined, df_2차누락숙소], ignore_index=True)

# %%
df_주중최종
# Out:
#              숙소ID   별점     리뷰수       주중판매가
# 0           23184  4.7   3,202       65000
# 1           23197  4.2   9,275       60000
# 2           23204  4.7     245       60000
# 3           23207  4.8  10,124  최대할인가55000
# 4           23216  4.6   4,501       45000
# ...           ...  ...     ...         ...
# 25158  1000109477  2.0       1      250000
# 25159  1000109538   없음      37        예약마감
# 25160  1000110771  4.8     201       40000
# 25161  1000111194  4.6   4,271        예약마감
# 25162  1000111408  5.0      30      160000
#
# [25163 rows x 4 columns]

# %% [markdown]
# - 별점, 리뷰수, 주중판매 정제

# %%
# 주중판매가 예약마감인 경우 삭제
df_주중최종 = df_주중최종[
    ~(
        (df_주중최종['주중판매가'] == '예약마감') | 
        (df_주중최종['주중판매가'] == '없음')
    )
]

# %%
# 별점 컬럼 nan이거나 없음 인 경우 삭제
df_주중최종 = df_주중최종[
    ~(
        (df_주중최종['별점'].isna()) | 
        (df_주중최종['별점'] == '없음') |
        (df_주중최종['별점'] == '후기')
    )
]

# %%
df_주중최종 = df_주중최종.drop_duplicates(subset=['숙소ID'], keep='first')

# %%
# df_주중최종 숙소 ID 중복 확인
df_주중최종.to_csv('야놀자_크롤링/주중최종숙소정보.csv', index=False)

# %%
df_주중최종
# Out:
#              숙소ID   별점     리뷰수       주중판매가
# 0           23184  4.7   3,202       65000
# 1           23197  4.2   9,275       60000
# 2           23204  4.7     245       60000
# 3           23207  4.8  10,124  최대할인가55000
# 4           23216  4.6   4,501       45000
# ...           ...  ...     ...         ...
# 25141  1000101206  3.0      32       45000
# 25144  1000109451  4.3     235       38000
# 25145  1000109477  2.0       1      250000
# 25147  1000110771  4.8     201       40000
# 25149  1000111408  5.0      30      160000
#
# [20852 rows x 4 columns]

# %%
missing_ids_final = sorted(set(df_메인['숙소ID']) - set(df_주중최종['숙소ID']))
df_missing = pd.DataFrame(missing_ids_final, columns=['숙소ID'])
df_missing.to_csv("누락_숙소ID_목록.csv", index=False)
df_missing
# Out:
#             숙소ID
# 0          23206
# 1          23271
# 2          23293
# 3          23312
# 4          23402
# ...          ...
# 6151  1000114444
# 6152  1000114446
# 6153  1000114487
# 6154  1000114540
# 6155  1000114543
#
# [6156 rows x 1 columns]

# %% [markdown]
# ## 3차 주중 누락 정제

# %%
import pandas as pd
df_주중누락3차 = pd.read_csv('야놀자_크롤링/3차누락숙소.csv')

# %%
df_주중누락3차
# Out:
#             숙소ID   별점     리뷰수   주중판매가
# 0          23206   없음   3,407    예약마감
# 1          23271  4.9   3,213    예약마감
# 2          23293   없음      없음      없음
# 3          23312   없음      없음      없음
# 4          23402  4.8  16,050    예약마감
# ...          ...  ...     ...     ...
# 6147  1000114444   없음       1    예약마감
# 6148  1000114446   없음      없음    예약마감
# 6149  1000114487   없음      없음    예약마감
# 6150  1000114540   없음       2  110000
# 6151  1000114543   없음       1    예약마감
#
# [6152 rows x 4 columns]

# %%
# df_주중누락3차 별점 컬럼이 nan이거나 없음 인 행 삭제
df_주중누락3차 = df_주중누락3차[
    ~(
        (df_주중누락3차['별점'].isna()) | 
        (df_주중누락3차['별점'] == '없음') |
        (df_주중누락3차['별점'] == '후기')
    )
]

# %%
# 주중판매가 예약마감인 경우 삭제
df_주중누락3차 = df_주중누락3차[
    ~(
        (df_주중누락3차['주중판매가'] == '예약마감') | 
        (df_주중누락3차['주중판매가'] == '없음')
    )   
]

# %%
df_주중누락3차.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 47 entries, 12 to 5830
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   숙소ID    47 non-null     int64
#  1   별점      47 non-null     object
#  2   리뷰수     47 non-null     object
#  3   주중판매가   47 non-null     object
# dtypes: int64(1), object(3)
# memory usage: 1.8+ KB

# %% [markdown]
# ## 4차정제

# %%
import pandas as pd
df_최종주중_v1 = pd.read_csv('야놀자_크롤링/주중최종숙소정보.csv')

# %%
# df_최종주중, df_주중누락3차 병합
df_최종주중_v1 = pd.concat([df_최종주중_v1, df_주중누락3차], ignore_index=True)

# %% [markdown]
# - 주중판매가 컬럼 (최대할인가) 삭제

# %%
df_최종주중_v1['주중판매가'] = df_최종주중_v1['주중판매가'].astype(str).str.replace('최대할인가', '', regex=False).str.strip()

# %%
df_최종주중_v1
# Out:
#              숙소ID   별점     리뷰수   주중판매가
# 0           23184  4.7   3,202   65000
# 1           23197  4.2   9,275   60000
# 2           23204  4.7     245   60000
# 3           23207  4.8  10,124   55000
# 4           23216  4.6   4,501   45000
# ...           ...  ...     ...     ...
# 20894  1000110449  4.8     395   45000
# 20895  1000110768  3.0       1  130000
# 20896  1000110770  4.8      34  105000
# 20897  1000111075  4.7     914   30000
# 20898  1000111265  4.4     259  140000
#
# [20899 rows x 4 columns]

# %%
df_최종주중_v1.to_csv('야놀자_크롤링/0806주중최종숙소정보v1.csv', index=False)

# %% [markdown]
# # 주말 및 주중 판매가 병합

# %%
import pandas as pd
df_clean_주중 = pd.read_csv('야놀자_크롤링/0806주중최종숙소정보v1.csv')
df_주말 = pd.read_csv('야놀자_크롤링/숙소정보_주말.csv')

# %% [markdown]
# - 별점 리뷰수는 삭제

# %%
df_주말
# Out:
#              숙소ID   별점    리뷰수        주말판매가
# 0           23184  4.7  3,205  최대할인가110000
# 1           23192  4.6    670        50000
# 2           23197  4.2  9,276       120000
# 3           23204  4.7    245        90000
# 4           23206   후기     없음         예약마감
# ...           ...  ...    ...          ...
# 26997  1000114540   후기     없음         예약마감
# 26998  1000114543   후기     없음         예약마감
# 26999  1000114558  2.7     38        80000
# 27000  1000114577  4.9    456       100000
# 27001  1000114675  4.9  1,169        80000
#
# [27002 rows x 4 columns]

# %%
# df_주말 별점 리뷰수는 삭제
df_주말 = df_주말.drop(columns=['별점', '리뷰수'])

# %%
df_주말
# Out:
#              숙소ID        주말판매가
# 0           23184  최대할인가110000
# 1           23192        50000
# 2           23197       120000
# 3           23204        90000
# 4           23206         예약마감
# ...           ...          ...
# 26997  1000114540         예약마감
# 26998  1000114543         예약마감
# 26999  1000114558        80000
# 27000  1000114577       100000
# 27001  1000114675        80000
#
# [27002 rows x 2 columns]

# %% [markdown]
# - 주말판매가 주중 데이터 프레임으로 병함

# %%
df_clean_주중
# Out:
#              숙소ID   별점     리뷰수   주중판매가
# 0           23184  4.7   3,202   65000
# 1           23197  4.2   9,275   60000
# 2           23204  4.7     245   60000
# 3           23207  4.8  10,124   55000
# 4           23216  4.6   4,501   45000
# ...           ...  ...     ...     ...
# 20894  1000110449  4.8     395   45000
# 20895  1000110768  3.0       1  130000
# 20896  1000110770  4.8      34  105000
# 20897  1000111075  4.7     914   30000
# 20898  1000111265  4.4     259  140000
#
# [20899 rows x 4 columns]

# %%
# 별점 컬럼이 nan이거나 없음 인 행 출력
df_clean_주중[df_clean_주중['별점'].isna() | (df_clean_주중['별점'] == '없음')]
# Out:
# Empty DataFrame
# Columns: [숙소ID, 별점, 리뷰수, 주중판매가]
# Index: []

# %%
# 리뷰수 컬럼이 nan이거나 없음 인 행 출력
df_clean_주중[df_clean_주중['리뷰수'].isna() | (df_clean_주중['리뷰수'] == '없음')]
# Out:
# Empty DataFrame
# Columns: [숙소ID, 별점, 리뷰수, 주중판매가]
# Index: []

# %%
# 주중판매가 컬럼이 예약마감이나 없음 인 행 출력
df_clean_주중[df_clean_주중['주중판매가'].isin(['예약마감', '없음'])]
# Out:
# Empty DataFrame
# Columns: [숙소ID, 별점, 리뷰수, 주중판매가]
# Index: []

# %%
# 숙소 ID 기준으로 df_주말 주말판매가 컬럼을 df_clean_주중에 병합
df_clean_주중 = df_clean_주중.merge(df_주말[['숙소ID', '주말판매가']], on='숙소ID', how='left')

# %%
df_clean_주중
# Out:
#              숙소ID   별점     리뷰수   주중판매가        주말판매가
# 0           23184  4.7   3,202   65000  최대할인가110000
# 1           23197  4.2   9,275   60000       120000
# 2           23204  4.7     245   60000        90000
# 3           23207  4.8  10,124   55000  최대할인가125000
# 4           23216  4.6   4,501   45000        90000
# ...           ...  ...     ...     ...          ...
# 20894  1000110449  4.8     395   45000         예약마감
# 20895  1000110768  3.0       1  130000       130000
# 20896  1000110770  4.8      34  105000         예약마감
# 20897  1000111075  4.7     914   30000         예약마감
# 20898  1000111265  4.4     259  140000       190000
#
# [20899 rows x 5 columns]

# %%
df_clean_주중.to_csv('야놀자_크롤링/0807_최종숙소판매가.csv', index=False)

# %%
# 주말 판매가 컬럼이 nan이거나 예약마감인행 출력
df_주말_누락 = df_clean_주중[
    (df_clean_주중['주말판매가'].isna()) | 
    (df_clean_주중['주말판매가'] == '예약마감') |
    (df_clean_주중['주말판매가'] == '없음')
]

# %%
df_주말_누락.to_csv('야놀자_크롤링/0806주말_누락숙소.csv', index=False)

# %% [markdown]
# ## 주말 판매가 정제

# %%
import pandas as pd
df_판매가 = pd.read_csv('야놀자_크롤링/0807_최종숙소판매가.csv')
df_주말크롤링 = pd.read_csv('야놀자_크롤링/1차주말누락숙소.csv')

# %%
df_판매가
# Out:
#              숙소ID   별점     리뷰수   주중판매가        주말판매가
# 0           23184  4.7   3,202   65000  최대할인가110000
# 1           23197  4.2   9,275   60000       120000
# 2           23204  4.7     245   60000        90000
# 3           23207  4.8  10,124   55000  최대할인가125000
# 4           23216  4.6   4,501   45000        90000
# ...           ...  ...     ...     ...          ...
# 20894  1000110449  4.8     395   45000         예약마감
# 20895  1000110768  3.0       1  130000       130000
# 20896  1000110770  4.8      34  105000         예약마감
# 20897  1000111075  4.7     914   30000         예약마감
# 20898  1000111265  4.4     259  140000       190000
#
# [20899 rows x 5 columns]

# %%
df_주말크롤링
# Out:
#             숙소ID   별점    리뷰수       주중판매가
# 0          23279  4.5     11       50000
# 1          23693  4.9  2,924       70000
# 2          24004  4.8  3,263  최대할인가57000
# 3          24102  4.4  4,606       66000
# 4          24452  4.6  4,660  최대할인가36000
# ...          ...  ...    ...         ...
# 4816  1000108078  4.3    570        예약마감
# 4817  1000109491  3.8     32      125000
# 4818  1000110449  4.8    397       48000
# 4819  1000110770  4.8     34      105000
# 4820  1000111075  4.7    914       40000
#
# [4821 rows x 4 columns]

# %%
# 컬럼 이름 변경
df_주말크롤링.rename(columns={'주중판매가': '주말판매가'}, inplace=True)

# %%
# 별점,리뷰수 삭제
df_주말크롤링 = df_주말크롤링.drop(columns=['별점', '리뷰수'])

# %%
# df_주말크롤링을 dict 형태로 변환 (숙소ID → 주말판매가)
주말가격_dict = df_주말크롤링.set_index('숙소ID')['주말판매가'].to_dict()

# df_판매가에서 숙소ID 기준으로 덮어쓰기 (없는 ID는 기존 값 유지)
df_판매가['주말판매가'] = df_판매가.apply(
    lambda row: 주말가격_dict.get(row['숙소ID'], row['주말판매가']),
    axis=1
)

# %%
# 예약 마감 인행 출력
df_판매가[df_판매가['주말판매가'].isin(['예약마감', '없음'])].to_csv('야놀자_크롤링/0807예약마감숙소.csv', index=False)

# %% [markdown]
# - 2차 정제

# %%
df_주말크롤링2차 = pd.read_csv('야놀자_크롤링/2차주말누락숙소.csv')

# %%
# df_주말크롤링을 dict 형태로 변환 (숙소ID → 주말판매가)
주말가격_dict1 = df_주말크롤링2차.set_index('숙소ID')['주말판매가'].to_dict()

# df_판매가에서 숙소ID 기준으로 덮어쓰기 (없는 ID는 기존 값 유지)
df_판매가['주말판매가'] = df_판매가.apply(
    lambda row: 주말가격_dict1.get(row['숙소ID'], row['주말판매가']),
    axis=1
)

# %%
df_판매가
# Out:
#              숙소ID   별점     리뷰수   주중판매가        주말판매가
# 0           23184  4.7   3,202   65000  최대할인가110000
# 1           23197  4.2   9,275   60000       120000
# 2           23204  4.7     245   60000        90000
# 3           23207  4.8  10,124   55000  최대할인가125000
# 4           23216  4.6   4,501   45000        90000
# ...           ...  ...     ...     ...          ...
# 20894  1000110449  4.8     395   45000        48000
# 20895  1000110768  3.0       1  130000       130000
# 20896  1000110770  4.8      34  105000       105000
# 20897  1000111075  4.7     914   30000        40000
# 20898  1000111265  4.4     259  140000       190000
#
# [20899 rows x 5 columns]

# %%
# 주말판매가가 NaN이거나 '예약마감', '없음'인 행 삭제
df_판매가 = df_판매가[
    ~(
        df_판매가['주말판매가'].isna() | 
        df_판매가['주말판매가'].isin(['예약마감', '없음'])
    )
]

# %%
df_판매가
# Out:
#              숙소ID   별점     리뷰수   주중판매가        주말판매가
# 0           23184  4.7   3,202   65000  최대할인가110000
# 1           23197  4.2   9,275   60000       120000
# 2           23204  4.7     245   60000        90000
# 3           23207  4.8  10,124   55000  최대할인가125000
# 4           23216  4.6   4,501   45000        90000
# ...           ...  ...     ...     ...          ...
# 20894  1000110449  4.8     395   45000        48000
# 20895  1000110768  3.0       1  130000       130000
# 20896  1000110770  4.8      34  105000       105000
# 20897  1000111075  4.7     914   30000        40000
# 20898  1000111265  4.4     259  140000       190000
#
# [20843 rows x 5 columns]

# %%
df_판매가['주말판매가'] = df_판매가['주말판매가'].str.replace('최대할인가', '', regex=False).str.strip()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_3752\4083423408.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_판매가['주말판매가'] = df_판매가['주말판매가'].str.replace('최대할인가', '', regex=False).str.strip()

# %%
df_판매가
# Out:
#              숙소ID   별점     리뷰수   주중판매가   주말판매가
# 0           23184  4.7   3,202   65000  110000
# 1           23197  4.2   9,275   60000  120000
# 2           23204  4.7     245   60000   90000
# 3           23207  4.8  10,124   55000  125000
# 4           23216  4.6   4,501   45000   90000
# ...           ...  ...     ...     ...     ...
# 20894  1000110449  4.8     395   45000   48000
# 20895  1000110768  3.0       1  130000  130000
# 20896  1000110770  4.8      34  105000  105000
# 20897  1000111075  4.7     914   30000   40000
# 20898  1000111265  4.4     259  140000  190000
#
# [20843 rows x 5 columns]

# %%
# 비정상 문자열 마스크 생성 (숫자 아님)
mask_주중 = ~df_판매가['주중판매가'].astype(str).str.replace(',', '').str.replace('.', '').str.isnumeric()

# 데이터프레임으로 추출
df_비정상_주중 = df_판매가[mask_주중].copy()

# 확인
df_비정상_주중.to_csv('야놀자_크롤링/비정상_주중판매가.csv', index=False)

# %%
mask_주말 = ~df_판매가['주말판매가'].astype(str).str.replace(',', '').str.replace('.', '').str.isnumeric()

df_비정상_주말 = df_판매가[mask_주말].copy()

df_비정상_주말.to_csv('야놀자_크롤링/비정상_주말판매가.csv', index=False)

# %% [markdown]
# - 비정상 판매가 매핑

# %%
df_비정상주중 = pd.read_csv('야놀자_크롤링/1비정상_주중판매가.csv')
df_비정상주말 = pd.read_csv('야놀자_크롤링/1비정상_주말판매가.csv')

# %%
df_비정상주말
# Out:
#           숙소ID  주말판매가
# 0        23411  75000
# 1        27653  55000
# 2        28171  63750
# 3      1003225  60000
# 4      1010912  44100
# 5      1012078  81000
# 6      3000161  49500
# 7      3000287  60000
# 8      3010744  65000
# 9      3016617  65000
# 10    10043249  45000
# 11    10043698  64000
# 12    10046297  48000
# 13  1000104211  50000
# 14  1000105067  85000
# 15  1000112401  58500
# 16  1000112491  53000

# %%
df_비정상주중
# Out:
#           숙소ID  주중판매가
# 0        23411  48000
# 1        27653  50000
# 2        28171  36975
# 3      1003225  50000
# 4      1010912  36000
# 5      1012078  45000
# 6      3000161  29700
# 7      3000287  38700
# 8      3010744  65000
# 9      3016617  40000
# 10    10043249  45000
# 11    10043698  55000
# 12    10046297  47000
# 13  1000104211  40000
# 14  1000105067  85000
# 15  1000112401  40000
# 16  1000112491  50000

# %%
# 주말/주중 가격 dict 생성
주말가격_dict = df_비정상주말.set_index('숙소ID')['주말판매가'].to_dict()
주중가격_dict = df_비정상주중.set_index('숙소ID')['주중판매가'].to_dict()

# 덮어쓰기: 숙소ID 기준으로 두 컬럼 모두 업데이트
df_판매가['주말판매가'] = df_판매가.apply(
    lambda row: 주말가격_dict.get(row['숙소ID'], row['주말판매가']),
    axis=1
)

df_판매가['주중판매가'] = df_판매가.apply(
    lambda row: 주중가격_dict.get(row['숙소ID'], row['주중판매가']),
    axis=1
)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_3752\3943170705.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_판매가['주말판매가'] = df_판매가.apply(
# C:\Users\user\AppData\Local\Temp\ipykernel_3752\3943170705.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_판매가['주중판매가'] = df_판매가.apply(

# %%
# 주중/주말 판매가를 숫자로 변환 (콤마 제거 및 float 처리)
df_판매가['주중판매가'] = df_판매가['주중판매가'].astype(str).str.replace(',', '').astype(float)
df_판매가['주말판매가'] = df_판매가['주말판매가'].astype(str).str.replace(',', '').astype(float)

# 0으로 나누는 에러 방지 후 비율 계산
df_판매가['판매가비율'] = df_판매가['주말판매가'] / df_판매가['주중판매가']

# (선택) 소수점 둘째자리까지 반올림
df_판매가['판매가비율'] = df_판매가['판매가비율'].round(2)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_3752\2644688941.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_판매가['주중판매가'] = df_판매가['주중판매가'].astype(str).str.replace(',', '').astype(float)
# C:\Users\user\AppData\Local\Temp\ipykernel_3752\2644688941.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_판매가['주말판매가'] = df_판매가['주말판매가'].astype(str).str.replace(',', '').astype(float)
# C:\Users\user\AppData\Local\Temp\ipykernel_3752\2644688941.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_판매가['판매가비율'] = df_판매가['주말판매가'] / df_판매가['주중판매가']
# C:\Users\user\AppData\Local\Temp\ipykernel_3752\2644688941.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_판매가['판매가비율'] = df_판매가['판매가비율'].round(2)

# %%
df_판매가.to_csv('야놀자_크롤링/0807_최종숙소판매가_v2.csv', index=False)

# %% [markdown]
# # 메인 데이터 프레임과 매핑

# %%
import pandas as pd
df_판매가_v1 = pd.read_csv('야놀자_크롤링/0807_최종숙소판매가_v2.csv')
df_main = pd.read_csv('0805_메인프레임v5.csv')
df_main.head()
# Out:
#    LDGS_CD          LDGS_NM  LDGS_TY_CD LDGMNT_TY_NM  LDGS_ZIP_NO  \
# 0    23184  영등포라이프스타일FHOTEL           1        Motel         7306
# 1    23192           청주오창M+           1        Motel        28118
# 2    23197             강남렉시           1        Motel         6235
# 3    23204         대전유성시나브로           1        Motel        34185
# 4    23206    부천(상동)MYHOTEL           1        Motel        14542
#
#              LDGS_ROAD_NM_ADDR    LDGS_LA     LDGS_LO CHIN_TIME CHOT_TIME  \
# 0   서울 영등포구 경인로108길 8 (영등포동1가)  37.517182  126.911217     23:00     12:00
# 1  충청북도 청주시 청원구 오창읍 양청송대길 9-12  36.713884  127.439228     18:00     12:00
# 2         서울특별시 강남구 테헤란로16길 11  37.498792  127.033956     23:00     13:00
# 3         대전광역시 유성구 온천북로59번길 9  36.356873  127.349172     17:00     13:00
# 4   경기도 부천시 길주로121번길 18-11(상동)  37.506612  126.756644       NaN       NaN
#
#   숙소 검색량(전체) 상위 시도 하위 시구   지역별_관심도  유튜브_상위20_평균조회수   가장 오래된 리뷰 error
# 0         20    서울  영등포구  3.057270          725000  2017.11.16   NaN
# 1         20    충북   청주시  2.802088           67961  2017.12.02   NaN
# 2        310    서울   강남구  3.057270          725000  2017.10.18   NaN
# 3         20    대전   유성구  2.918471          155050  2017.12.09   NaN
# 4         20    경기   부천시  2.928911          246000  2020.03.19   NaN

# %%
# df_main 컬럼 이름 변경
df_main.rename(columns={'LDGS_CD': '숙소ID'}, inplace=True)

# %%
# df_main 과 df_판매가  숙소 ID 기준으로 매핑
df_final = df_main.merge(df_판매가_v1, on='숙소ID', how='left')

# %%
# 주중판매가가 NaN인경우 삭제
df_final = df_final.dropna(subset=['주중판매가'])

# %%
df_final.to_csv('0807_메인프레임v6.csv', index=False)

# %% [markdown]
# - CHIN_TIME	이 NaN인 경우

# %%
# CHIN_TIME	이 NaN인 경우 출력
df_final[df_final['CHIN_TIME'].isna()].to_csv('0807체크인아웃누락v1.csv', index=False)

# %% [markdown]
# ## 체크인, 체크아웃

# %%
import pandas as pd
df_체크인아웃 = pd.read_csv('야놀자_체크인아웃_펜션.csv')
df_체크아웃오류 = pd.read_csv('야놀자_체크인아웃_펜션누락.csv')

# %% [markdown]
# - 오류 18개 확인

# %% [markdown]
# - 펜션 정제

# %%
df_체크인아웃
# Out:
#          LDGS_CD              체크인             체크아웃
# 0        3002660  15:00 ~ 22:00까지  12:00 ~ 12:00까지
# 1        3003230  15:00 ~ 22:00까지  11:00 ~ 11:00까지
# 2        3003564  16:00 ~ 22:00까지  12:00 ~ 12:00까지
# 3        3003733  15:00 ~ 22:00까지  11:00 ~ 11:00까지
# 4        3004038  15:00 ~ 22:00까지  11:00 ~ 11:00까지
# ...          ...              ...              ...
# 2231  1000110022  15:00 ~ 22:00까지  11:00 ~ 11:00까지
# 2232  1000110146  15:00 ~ 22:00까지  10:50 ~ 11:00까지
# 2233  1000110310  14:00 ~ 22:00까지  11:00 ~ 11:00까지
# 2234  1000112592  15:00 ~ 22:00까지  11:00 ~ 11:00까지
# 2235  1000113573  15:00 ~ 22:00까지  11:00 ~ 11:00까지
#
# [2236 rows x 3 columns]

# %%
# 체크인과 체크아웃에서 ~ 앞부분만 남기기
df_체크인아웃['체크인'] = df_체크인아웃['체크인'].str.split('~').str[0].str.strip()
df_체크인아웃['체크아웃'] = df_체크인아웃['체크아웃'].str.split('~').str[0].str.strip()

df_체크인아웃
# Out:
#          LDGS_CD    체크인   체크아웃
# 0        3002660  15:00  12:00
# 1        3003230  15:00  11:00
# 2        3003564  16:00  12:00
# 3        3003733  15:00  11:00
# 4        3004038  15:00  11:00
# ...          ...    ...    ...
# 2231  1000110022  15:00  11:00
# 2232  1000110146  15:00  10:50
# 2233  1000110310  14:00  11:00
# 2234  1000112592  15:00  11:00
# 2235  1000113573  15:00  11:00
#
# [2236 rows x 3 columns]

# %%
df_체크아웃오류
# Out:
#      LDGS_CD    체크인   체크아웃
# 0   10050064  13:00  12:00
# 1   10053454  정보 없음  정보 없음
# 2   10056072  정보 없음  정보 없음
# 3   10056206  15:00  11:00
# 4   10056691  15:00  11:00
# 5   10056850  15:00  11:00
# 6   10056936  15:00  11:00
# 7   10058197  15:00  11:00
# 8   10058645  15:00  11:00
# 9   10058653  15:00  12:00
# 10  10058915  15:00  11:00
# 11  10059498  15:00  11:00
# 12  10059944  15:00  11:00
# 13  10060213  16:00  11:00
# 14  10060760  15:00  11:00
# 15  10060837  15:00  11:00
# 16  10060929  16:00  11:00
# 17  10061003  15:00  12:00

# %%
# LDGS_CD 기준으로 체크인/체크아웃 덮어쓰기
df_체크인아웃.update(
    df_체크인아웃[['LDGS_CD']].merge(
        df_체크아웃오류[['LDGS_CD', '체크인', '체크아웃']],
        on='LDGS_CD',
        how='left'
    )
)

# 결과 확인
df_체크인아웃
# Out:
#          LDGS_CD    체크인   체크아웃
# 0        3002660  15:00  12:00
# 1        3003230  15:00  11:00
# 2        3003564  16:00  12:00
# 3        3003733  15:00  11:00
# 4        3004038  15:00  11:00
# ...          ...    ...    ...
# 2231  1000110022  15:00  11:00
# 2232  1000110146  15:00  10:50
# 2233  1000110310  14:00  11:00
# 2234  1000112592  15:00  11:00
# 2235  1000113573  15:00  11:00
#
# [2236 rows x 3 columns]

# %%
# df_체크인아웃 정보 없음인 행 출력
df_체크인아웃[df_체크인아웃['체크인'] == '정보 없음']
# Out:
#       LDGS_CD    체크인   체크아웃
# 125  10053454  정보 없음  정보 없음
# 490  10056072  정보 없음  정보 없음

# %% [markdown]
# - 모텔 정제

# %%
df_모텔체크인 = pd.read_csv('야놀자_체크인아웃_모텔.csv')
df_모텔체크인
# Out:
#         LDGS_CD    체크인   체크아웃
# 0         23227  18:00  12:00
# 1         23242  14:00  13:00
# 2         23279  17:00  12:00
# 3         23315  12:00  14:00
# 4         23342  17:00  13:00
# ..          ...    ...    ...
# 686  1000113000  17:00  12:00
# 687  1000113251  15:00  11:00
# 688  1000113255  14:00  11:00
# 689  1000114246  15:00  11:00
# 690  1000114274  16:00  12:00
#
# [691 rows x 3 columns]

# %%
# 정보 없음 출력
df_모텔체크인[df_모텔체크인['체크인'] == '정보 없음']
# Out:
#       LDGS_CD    체크인   체크아웃
# 193  10041576  정보 없음  정보 없음

# %%
# 10041576인행 체크인은 16:00 , 체크아웃은 12:00 로 변경
df_모텔체크인.loc[df_모텔체크인['LDGS_CD'] == 10041576, '체크인'] = '16:00'
df_모텔체크인.loc[df_모텔체크인['LDGS_CD'] == 10041576, '체크아웃'] = '12:00'

# %% [markdown]
# - 게스트 하우스 정제

# %%
df_게하체크인 = pd.read_csv('야놀자_체크인아웃_게스트하우스.csv')

# %%
# 정보 없음 출력
df_모텔체크인[df_모텔체크인['체크인'] == '정보 없음']
# Out:
# Empty DataFrame
# Columns: [LDGS_CD, 체크인, 체크아웃]
# Index: []

# %% [markdown]
# - 호텔 정제

# %%
# 전체행 출력
pd.reset_option('display.max_rows')

# %%
df_호텔체크인 = pd.read_csv('야놀자_체크인아웃_호텔.csv')
df_호텔체크인
# Out:
#         LDGS_CD    체크인   체크아웃
# 0       3000905  15:00  11:00
# 1       3001044  14:00  12:00
# 2       3001047  16:00  11:00
# 3       3001091  15:00  12:00
# 4       3001216  15:00  12:00
# ..          ...    ...    ...
# 365    10061164  19:00  10:00
# 366    10061194  16:00  11:00
# 367  1000099324  19:00  12:00
# 368  1000101988  15:00  11:00
# 369  1000114218  15:00  11:00
#
# [370 rows x 3 columns]

# %%
# 컬럼명 변경
df_호텔체크인.rename(columns={'LDGS_CD': '숙소ID'}, inplace=True)

# %%
# 호텔 정보 없음 출력
df_호텔체크인[df_호텔체크인['체크인'] == '정보 없음'].to_csv('야놀자_체크인아웃_호텔누락.csv', index=False)

# %%
df_호텔체크인누락 = pd.read_csv('야놀자_체크인아웃_호텔정보없음.csv')
df_호텔체크인누락
# Out:
#         숙소ID    체크인   체크아웃
# 0    3016545  정보 없음  정보 없음
# 1   10047743  16:00  12:00
# 2   10048796  14:00  11:00
# 3   10048814  15:00  11:00
# 4   10052562  정보 없음  정보 없음
# 5   10052726  정보 없음  정보 없음
# 6   10056996  16:00  11:00
# 7   10058361  정보 없음  정보 없음
# 8   10058904  정보 없음  정보 없음
# 9   10059104  15:00  11:00
# 10  10059766  15:00  11:00
# 11  10059888  15:00  11:00
# 12  10060141  15:00  11:00
# 13  10060184  15:00  11:00
# 14  10060274  15:00  11:00
# 15  10060285  15:00  11:00
# 16  10060313  15:00  11:00
# 17  10060347  15:00  11:00
# 18  10060470  15:00  12:00
# 19  10060673  15:00  11:00
# 20  10060733  정보 없음  정보 없음
# 21  10060747  16:00  11:00
# 22  10061032  16:00  11:00

# %%
# 숙소ID 기준으로 CHIN_TIME, CHOT_TIME 덮어쓰기
df_호텔체크인.update(
    df_호텔체크인[['숙소ID']].merge(
        df_호텔체크인누락[['숙소ID', '체크인', '체크아웃']],
        on='숙소ID',
        how='left'
    )
)

# %%
# 정보 없음 출력
df_호텔체크인[df_호텔체크인['체크인'] == '정보 없음']
# Out:
#          숙소ID    체크인   체크아웃
# 10    3016545  정보 없음  정보 없음
# 29   10052562  정보 없음  정보 없음
# 30   10052726  정보 없음  정보 없음
# 195  10058361  정보 없음  정보 없음
# 222  10058904  정보 없음  정보 없음
# 340  10060733  정보 없음  정보 없음

# %%
# 3016545
df_호텔체크인.loc[df_호텔체크인['숙소ID'] == 3016545, '체크인'] = '15:00'
df_호텔체크인.loc[df_호텔체크인['숙소ID'] == 3016545, '체크아웃'] = '12:00'

# 10052562
df_호텔체크인.loc[df_호텔체크인['숙소ID'] == 10052562, '체크인'] = '13:00'
df_호텔체크인.loc[df_호텔체크인['숙소ID'] == 10052562, '체크아웃'] = '10:00'

# 10052726
df_호텔체크인.loc[df_호텔체크인['숙소ID'] == 10052726, '체크인'] = '15:00'
df_호텔체크인.loc[df_호텔체크인['숙소ID'] == 10052726, '체크아웃'] = '11:00'

# 10058904
df_호텔체크인.loc[df_호텔체크인['숙소ID'] == 10058904, '체크인'] = '16:00'
df_호텔체크인.loc[df_호텔체크인['숙소ID'] == 10058904, '체크아웃'] = '11:00'

# %%
# 정보 없음 출력
df_호텔체크인[df_호텔체크인['체크인'] == '정보 없음']
# Out:
#          숙소ID    체크인   체크아웃
# 195  10058361  정보 없음  정보 없음
# 340  10060733  정보 없음  정보 없음

# %%
# 컬럼 명 변경
df_호텔체크인.rename(columns={'숙소ID':'LDGS_CD'}, inplace=True)

# %%
# df_체크인아웃, df_모텔체크인, df_게하체크인, df_호텔체크인 병합
df_체크인아웃_최종 = pd.concat([df_체크인아웃, df_모텔체크인, df_게하체크인, df_호텔체크인], ignore_index=True)

# %%
# 컬럼명 변경 , CHOT_TIME,CHIN_TIME
df_체크인아웃_최종.rename(columns={'체크아웃': 'CHOT_TIME', '체크인': 'CHIN_TIME','LDGS_CD': '숙소ID' }, inplace=True)

# %%
df_체크인아웃_최종
# Out:
#             숙소ID CHIN_TIME CHOT_TIME
# 0        3002660     15:00     12:00
# 1        3003230     15:00     11:00
# 2        3003564     16:00     12:00
# 3        3003733     15:00     11:00
# 4        3004038     15:00     11:00
# ...          ...       ...       ...
# 3316    10061164     19:00     10:00
# 3317    10061194     16:00     11:00
# 3318  1000099324     19:00     12:00
# 3319  1000101988     15:00     11:00
# 3320  1000114218     15:00     11:00
#
# [3321 rows x 3 columns]

# %% [markdown]
# ## 체크인 데이터 프레임과 메인프레임 병합

# %%
import pandas as pd
df_메인프레임1 = pd.read_csv('0807_메인프레임v6.csv')
df_메인프레임1
# Out:
#              숙소ID              LDGS_NM  LDGS_TY_CD LDGMNT_TY_NM  LDGS_ZIP_NO  \
# 0           23184      영등포라이프스타일FHOTEL           1        Motel         7306
# 1           23192               청주오창M+           1        Motel        28118
# 2           23197                 강남렉시           1        Motel         6235
# 3           23204             대전유성시나브로           1        Motel        34185
# 4           23207                  역삼벤           1        Motel         6220
# ...           ...                  ...         ...          ...          ...
# 20838  1000114526             전주중노송동파인           1        Motel        55000
# 20839  1000114529        거창서핑파크리조트&글램핑           2        Hotel        50103
# 20840  1000114558                 여수굿썸           1        Motel        59769
# 20841  1000114577          순천브라운도트순천역점           1        Motel        57964
# 20842  1000114675  인천(검단)브라운도트인천검단사거리점           1        Motel        22636
#
#                  LDGS_ROAD_NM_ADDR    LDGS_LA     LDGS_LO CHIN_TIME CHOT_TIME  \
# 0       서울 영등포구 경인로108길 8 (영등포동1가)  37.517182  126.911217     23:00     12:00
# 1      충청북도 청주시 청원구 오창읍 양청송대길 9-12  36.713884  127.439228     18:00     12:00
# 2             서울특별시 강남구 테헤란로16길 11  37.498792  127.033956     23:00     13:00
# 3             대전광역시 유성구 온천북로59번길 9  36.356873  127.349172     17:00     13:00
# 4           서울 강남구 언주로87길 41 (역삼동)  37.500706  127.039849     23:00     12:00
# ...                            ...        ...         ...       ...       ...
# 20838         전라북도 전주시 완산구 현무3길 54  35.822097  127.150451     16:00     12:00
# 20839      경상남도 거창군 위천면 거차1길 23-18  35.747967  127.836350     15:00     11:00
# 20840          전라남도 여수시 돌산읍 강남로 45  34.719781  127.750254     15:00     11:00
# 20841             전라남도 순천시 팔마로 153  34.944613  127.504991     23:00     11:00
# 20842    인천광역시 서구 완정로117번길 31(왕길동)  37.600624  126.659497     22:00     12:00
#
#        ... 하위 시구   지역별_관심도 유튜브_상위20_평균조회수   가장 오래된 리뷰           error   별점  \
# 0      ...  영등포구  3.057270         725000  2017.11.16             NaN  4.7
# 1      ...   청주시  2.802088          67961  2017.12.02             NaN  4.6
# 2      ...   강남구  3.057270         725000  2017.10.18             NaN  4.2
# 3      ...   유성구  2.918471         155050  2017.12.09             NaN  4.7
# 4      ...   강남구  3.057270         725000  2017.10.23             NaN  4.8
# ...    ...   ...       ...            ...         ...             ...  ...
# 20838  ...   전주시  2.833871         120072         NaN   날짜 형식 오류: 일반실  3.3
# 20839  ...   거창군  2.794718         131945  2021.10.10             NaN  4.3
# 20840  ...   여수시  2.923691          70700         NaN  날짜 형식 오류: 스탠다드  2.7
# 20841  ...   순천시  2.923691          70700  2021.10.03             NaN  4.9
# 20842  ...    서구  2.928911         264000  2021.09.29             NaN  4.9
#
#           리뷰수     주중판매가     주말판매가  판매가비율
# 0       3,202   65000.0  110000.0   1.69
# 1         670   55000.0   50000.0   0.91
# 2       9,275   60000.0  120000.0   2.00
# 3         245   60000.0   90000.0   1.50
# 4      10,124   55000.0  125000.0   2.27
# ...       ...       ...       ...    ...
# 20838      64   45000.0   60000.0   1.33
# 20839      51  115000.0  140000.0   1.22
# 20840      38   60000.0   80000.0   1.33
# 20841     456   70000.0  100000.0   1.43
# 20842   1,168   55000.0   80000.0   1.45
#
# [20843 rows x 22 columns]

# %%
df_체크인아웃_최종
# Out:
#             숙소ID CHIN_TIME CHOT_TIME
# 0        3002660     15:00     12:00
# 1        3003230     15:00     11:00
# 2        3003564     16:00     12:00
# 3        3003733     15:00     11:00
# 4        3004038     15:00     11:00
# ...          ...       ...       ...
# 3316    10061164     19:00     10:00
# 3317    10061194     16:00     11:00
# 3318  1000099324     19:00     12:00
# 3319  1000101988     15:00     11:00
# 3320  1000114218     15:00     11:00
#
# [3321 rows x 3 columns]

# %%
# 정보 없음 출력
df_체크인아웃_최종[df_체크인아웃_최종['CHIN_TIME'] == '정보 없음']
# Out:
#           숙소ID CHIN_TIME CHOT_TIME
# 125   10053454     정보 없음     정보 없음
# 490   10056072     정보 없음     정보 없음
# 2939  10042911     정보 없음     정보 없음
# 3146  10058361     정보 없음     정보 없음
# 3291  10060733     정보 없음     정보 없음

# %% [markdown]
# - 체크인 시간과 메인프레임 병합

# %%
# 숙소ID 기준으로 CHIN_TIME, CHOT_TIME 덮어쓰기
df_메인프레임1.update(
    df_메인프레임1[['숙소ID']].merge(
        df_체크인아웃_최종[['숙소ID', 'CHIN_TIME', 'CHOT_TIME']],
        on='숙소ID',
        how='left'
    )
)

# 결과 확인
df_메인프레임1
# Out:
#              숙소ID              LDGS_NM  LDGS_TY_CD LDGMNT_TY_NM  LDGS_ZIP_NO  \
# 0           23184      영등포라이프스타일FHOTEL           1        Motel         7306
# 1           23192               청주오창M+           1        Motel        28118
# 2           23197                 강남렉시           1        Motel         6235
# 3           23204             대전유성시나브로           1        Motel        34185
# 4           23207                  역삼벤           1        Motel         6220
# ...           ...                  ...         ...          ...          ...
# 20838  1000114526             전주중노송동파인           1        Motel        55000
# 20839  1000114529        거창서핑파크리조트&글램핑           2        Hotel        50103
# 20840  1000114558                 여수굿썸           1        Motel        59769
# 20841  1000114577          순천브라운도트순천역점           1        Motel        57964
# 20842  1000114675  인천(검단)브라운도트인천검단사거리점           1        Motel        22636
#
#                  LDGS_ROAD_NM_ADDR    LDGS_LA     LDGS_LO CHIN_TIME CHOT_TIME  \
# 0       서울 영등포구 경인로108길 8 (영등포동1가)  37.517182  126.911217     23:00     12:00
# 1      충청북도 청주시 청원구 오창읍 양청송대길 9-12  36.713884  127.439228     18:00     12:00
# 2             서울특별시 강남구 테헤란로16길 11  37.498792  127.033956     23:00     13:00
# 3             대전광역시 유성구 온천북로59번길 9  36.356873  127.349172     17:00     13:00
# 4           서울 강남구 언주로87길 41 (역삼동)  37.500706  127.039849     23:00     12:00
# ...                            ...        ...         ...       ...       ...
# 20838         전라북도 전주시 완산구 현무3길 54  35.822097  127.150451     16:00     12:00
# 20839      경상남도 거창군 위천면 거차1길 23-18  35.747967  127.836350     15:00     11:00
# 20840          전라남도 여수시 돌산읍 강남로 45  34.719781  127.750254     15:00     11:00
# 20841             전라남도 순천시 팔마로 153  34.944613  127.504991     23:00     11:00
# 20842    인천광역시 서구 완정로117번길 31(왕길동)  37.600624  126.659497     22:00     12:00
#
#        ... 하위 시구   지역별_관심도 유튜브_상위20_평균조회수   가장 오래된 리뷰           error   별점  \
# 0      ...  영등포구  3.057270         725000  2017.11.16             NaN  4.7
# 1      ...   청주시  2.802088          67961  2017.12.02             NaN  4.6
# 2      ...   강남구  3.057270         725000  2017.10.18             NaN  4.2
# 3      ...   유성구  2.918471         155050  2017.12.09             NaN  4.7
# 4      ...   강남구  3.057270         725000  2017.10.23             NaN  4.8
# ...    ...   ...       ...            ...         ...             ...  ...
# 20838  ...   전주시  2.833871         120072         NaN   날짜 형식 오류: 일반실  3.3
# 20839  ...   거창군  2.794718         131945  2021.10.10             NaN  4.3
# 20840  ...   여수시  2.923691          70700         NaN  날짜 형식 오류: 스탠다드  2.7
# 20841  ...   순천시  2.923691          70700  2021.10.03             NaN  4.9
# 20842  ...    서구  2.928911         264000  2021.09.29             NaN  4.9
#
#           리뷰수     주중판매가     주말판매가  판매가비율
# 0       3,202   65000.0  110000.0   1.69
# 1         670   55000.0   50000.0   0.91
# 2       9,275   60000.0  120000.0   2.00
# 3         245   60000.0   90000.0   1.50
# 4      10,124   55000.0  125000.0   2.27
# ...       ...       ...       ...    ...
# 20838      64   45000.0   60000.0   1.33
# 20839      51  115000.0  140000.0   1.22
# 20840      38   60000.0   80000.0   1.33
# 20841     456   70000.0  100000.0   1.43
# 20842   1,168   55000.0   80000.0   1.45
#
# [20843 rows x 22 columns]

# %%
# 정보 없음 은 삭제
df_메인프레임1 = df_메인프레임1[df_메인프레임1['CHIN_TIME'] != '정보 없음']

# %%
df_메인프레임1
# Out:
#              숙소ID              LDGS_NM  LDGS_TY_CD LDGMNT_TY_NM  LDGS_ZIP_NO  \
# 0           23184      영등포라이프스타일FHOTEL           1        Motel         7306
# 1           23192               청주오창M+           1        Motel        28118
# 2           23197                 강남렉시           1        Motel         6235
# 3           23204             대전유성시나브로           1        Motel        34185
# 4           23207                  역삼벤           1        Motel         6220
# ...           ...                  ...         ...          ...          ...
# 20838  1000114526             전주중노송동파인           1        Motel        55000
# 20839  1000114529        거창서핑파크리조트&글램핑           2        Hotel        50103
# 20840  1000114558                 여수굿썸           1        Motel        59769
# 20841  1000114577          순천브라운도트순천역점           1        Motel        57964
# 20842  1000114675  인천(검단)브라운도트인천검단사거리점           1        Motel        22636
#
#                  LDGS_ROAD_NM_ADDR    LDGS_LA     LDGS_LO CHIN_TIME CHOT_TIME  \
# 0       서울 영등포구 경인로108길 8 (영등포동1가)  37.517182  126.911217     23:00     12:00
# 1      충청북도 청주시 청원구 오창읍 양청송대길 9-12  36.713884  127.439228     18:00     12:00
# 2             서울특별시 강남구 테헤란로16길 11  37.498792  127.033956     23:00     13:00
# 3             대전광역시 유성구 온천북로59번길 9  36.356873  127.349172     17:00     13:00
# 4           서울 강남구 언주로87길 41 (역삼동)  37.500706  127.039849     23:00     12:00
# ...                            ...        ...         ...       ...       ...
# 20838         전라북도 전주시 완산구 현무3길 54  35.822097  127.150451     16:00     12:00
# 20839      경상남도 거창군 위천면 거차1길 23-18  35.747967  127.836350     15:00     11:00
# 20840          전라남도 여수시 돌산읍 강남로 45  34.719781  127.750254     15:00     11:00
# 20841             전라남도 순천시 팔마로 153  34.944613  127.504991     23:00     11:00
# 20842    인천광역시 서구 완정로117번길 31(왕길동)  37.600624  126.659497     22:00     12:00
#
#        ... 하위 시구   지역별_관심도 유튜브_상위20_평균조회수   가장 오래된 리뷰           error   별점  \
# 0      ...  영등포구  3.057270         725000  2017.11.16             NaN  4.7
# 1      ...   청주시  2.802088          67961  2017.12.02             NaN  4.6
# 2      ...   강남구  3.057270         725000  2017.10.18             NaN  4.2
# 3      ...   유성구  2.918471         155050  2017.12.09             NaN  4.7
# 4      ...   강남구  3.057270         725000  2017.10.23             NaN  4.8
# ...    ...   ...       ...            ...         ...             ...  ...
# 20838  ...   전주시  2.833871         120072         NaN   날짜 형식 오류: 일반실  3.3
# 20839  ...   거창군  2.794718         131945  2021.10.10             NaN  4.3
# 20840  ...   여수시  2.923691          70700         NaN  날짜 형식 오류: 스탠다드  2.7
# 20841  ...   순천시  2.923691          70700  2021.10.03             NaN  4.9
# 20842  ...    서구  2.928911         264000  2021.09.29             NaN  4.9
#
#           리뷰수     주중판매가     주말판매가  판매가비율
# 0       3,202   65000.0  110000.0   1.69
# 1         670   55000.0   50000.0   0.91
# 2       9,275   60000.0  120000.0   2.00
# 3         245   60000.0   90000.0   1.50
# 4      10,124   55000.0  125000.0   2.27
# ...       ...       ...       ...    ...
# 20838      64   45000.0   60000.0   1.33
# 20839      51  115000.0  140000.0   1.22
# 20840      38   60000.0   80000.0   1.33
# 20841     456   70000.0  100000.0   1.43
# 20842   1,168   55000.0   80000.0   1.45
#
# [20838 rows x 22 columns]

# %%
df_메인프레임1.to_csv('0808_메인프레임v7.csv', index=False)

# %%
df_메인프레임1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20838 entries, 0 to 20842
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   숙소ID               20838 non-null  int64
#  1   LDGS_NM            20838 non-null  object
#  2   LDGS_TY_CD         20838 non-null  int64
#  3   LDGMNT_TY_NM       20838 non-null  object
#  4   LDGS_ZIP_NO        20838 non-null  int64
#  5   LDGS_ROAD_NM_ADDR  20838 non-null  object
#  6   LDGS_LA            20838 non-null  float64
#  7   LDGS_LO            20838 non-null  float64
#  8   CHIN_TIME          20838 non-null  object
#  9   CHOT_TIME          20838 non-null  object
#  10  숙소 검색량(전체)         20838 non-null  object
#  11  상위 시도              20838 non-null  object
#  12  하위 시구              20838 non-null  object
#  13  지역별_관심도            20838 non-null  float64
#  14  유튜브_상위20_평균조회수     20838 non-null  int64
#  15  가장 오래된 리뷰          13449 non-null  object
#  16  error              7389 non-null   object
#  17  별점                 20838 non-null  float64
#  18  리뷰수                20838 non-null  object
#  19  주중판매가              20838 non-null  float64
#  20  주말판매가              20838 non-null  float64
#  21  판매가비율              20838 non-null  float64
# dtypes: float64(7), int64(4), object(11)
# memory usage: 3.7+ MB

# %% [markdown]
# # 최초 리뷰 등록일 매핑

# %%
import pandas as pd

df_main0811 = pd.read_csv('0808_메인프레임v7.csv')
df_리뷰 = pd.read_csv('0808_메인프레임v8.csv')

# %%
df_리뷰.head()
# Out:
#    LDGS_CD          LDGS_NM  LDGS_TY_CD LDGMNT_TY_NM  LDGS_ZIP_NO  \
# 0    23184  영등포라이프스타일FHOTEL           1        Motel         7306
# 1    23192           청주오창M+           1        Motel        28118
# 2    23197             강남렉시           1        Motel         6235
# 3    23204         대전유성시나브로           1        Motel        34185
# 4    23206    부천(상동)MYHOTEL           1        Motel        14542
#
#              LDGS_ROAD_NM_ADDR    LDGS_LA     LDGS_LO CHIN_TIME CHOT_TIME  \
# 0   서울 영등포구 경인로108길 8 (영등포동1가)  37.517182  126.911217     23:00     12:00
# 1  충청북도 청주시 청원구 오창읍 양청송대길 9-12  36.713884  127.439228     18:00     12:00
# 2         서울특별시 강남구 테헤란로16길 11  37.498792  127.033956     23:00     13:00
# 3         대전광역시 유성구 온천북로59번길 9  36.356873  127.349172     17:00     13:00
# 4   경기도 부천시 길주로121번길 18-11(상동)  37.506612  126.756644       NaN       NaN
#
#   숙소 검색량(전체) 상위 시도 하위 시구   지역별_관심도  유튜브_상위20_평균조회수   가장 오래된 리뷰 error
# 0         20    서울  영등포구  3.057270          725000  2017.11.16   NaN
# 1         20    충북   청주시  2.802088           67961  2017.12.02   NaN
# 2        310    서울   강남구  3.057270          725000  2017.10.18   NaN
# 3         20    대전   유성구  2.918471          155050  2017.12.09   NaN
# 4         20    경기   부천시  2.928911          246000  2020.03.19   NaN

# %%
df_리뷰.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27008 entries, 0 to 27007
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   LDGS_CD            27008 non-null  int64
#  1   LDGS_NM            27008 non-null  object
#  2   LDGS_TY_CD         27008 non-null  int64
#  3   LDGMNT_TY_NM       27008 non-null  object
#  4   LDGS_ZIP_NO        27008 non-null  int64
#  5   LDGS_ROAD_NM_ADDR  27008 non-null  object
#  6   LDGS_LA            27008 non-null  float64
#  7   LDGS_LO            27008 non-null  float64
#  8   CHIN_TIME          21778 non-null  object
#  9   CHOT_TIME          21778 non-null  object
#  10  숙소 검색량(전체)         27008 non-null  object
#  11  상위 시도              27008 non-null  object
#  12  하위 시구              27008 non-null  object
#  13  지역별_관심도            27008 non-null  float64
#  14  유튜브_상위20_평균조회수     27008 non-null  int64
#  15  가장 오래된 리뷰          25288 non-null  object
#  16  error              12434 non-null  object
# dtypes: float64(3), int64(4), object(10)
# memory usage: 3.5+ MB

# %%
# LDGS_CD, 가장 오래된 리뷰 컬럼만 저장
df_subset = df_리뷰[['LDGS_CD', '가장 오래된 리뷰']]

# %%
# LDGS_CD 컬럼명 변경
df_subset = df_subset.rename(columns={'LDGS_CD': '숙소ID'})

# %%
df_subset
# Out:
#              숙소ID   가장 오래된 리뷰
# 0           23184  2017.11.16
# 1           23192  2017.12.02
# 2           23197  2017.10.18
# 3           23204  2017.12.09
# 4           23206  2020.03.19
# ...           ...         ...
# 27003  1000114540  2022.11.01
# 27004  1000114543  2022.09.27
# 27005  1000114558  2021.06.07
# 27006  1000114577  2021.10.03
# 27007  1000114675  2021.09.29
#
# [27008 rows x 2 columns]

# %%
df_main0811.head()
# Out:
#     숙소ID          LDGS_NM  LDGS_TY_CD LDGMNT_TY_NM  LDGS_ZIP_NO  \
# 0  23184  영등포라이프스타일FHOTEL           1        Motel         7306
# 1  23192           청주오창M+           1        Motel        28118
# 2  23197             강남렉시           1        Motel         6235
# 3  23204         대전유성시나브로           1        Motel        34185
# 4  23207              역삼벤           1        Motel         6220
#
#              LDGS_ROAD_NM_ADDR    LDGS_LA     LDGS_LO CHIN_TIME CHOT_TIME  \
# 0   서울 영등포구 경인로108길 8 (영등포동1가)  37.517182  126.911217     23:00     12:00
# 1  충청북도 청주시 청원구 오창읍 양청송대길 9-12  36.713884  127.439228     18:00     12:00
# 2         서울특별시 강남구 테헤란로16길 11  37.498792  127.033956     23:00     13:00
# 3         대전광역시 유성구 온천북로59번길 9  36.356873  127.349172     17:00     13:00
# 4       서울 강남구 언주로87길 41 (역삼동)  37.500706  127.039849     23:00     12:00
#
#    ... 하위 시구   지역별_관심도 유튜브_상위20_평균조회수   가장 오래된 리뷰  error   별점     리뷰수  \
# 0  ...  영등포구  3.057270         725000  2017.11.16    NaN  4.7   3,202
# 1  ...   청주시  2.802088          67961  2017.12.02    NaN  4.6     670
# 2  ...   강남구  3.057270         725000  2017.10.18    NaN  4.2   9,275
# 3  ...   유성구  2.918471         155050  2017.12.09    NaN  4.7     245
# 4  ...   강남구  3.057270         725000  2017.10.23    NaN  4.8  10,124
#
#      주중판매가     주말판매가  판매가비율
# 0  65000.0  110000.0   1.69
# 1  55000.0   50000.0   0.91
# 2  60000.0  120000.0   2.00
# 3  60000.0   90000.0   1.50
# 4  55000.0  125000.0   2.27
#
# [5 rows x 22 columns]

# %% [markdown]
# - 리뷰 날짜 프레임과 메인프레임 병합

# %%
# 병합
df_merged = df_main0811.merge(
    df_subset,
    how='left',
    left_on='숙소ID',
    right_on='숙소ID'
)

# 확인
df_merged.head()
# Out:
#     숙소ID          LDGS_NM  LDGS_TY_CD LDGMNT_TY_NM  LDGS_ZIP_NO  \
# 0  23184  영등포라이프스타일FHOTEL           1        Motel         7306
# 1  23192           청주오창M+           1        Motel        28118
# 2  23197             강남렉시           1        Motel         6235
# 3  23204         대전유성시나브로           1        Motel        34185
# 4  23207              역삼벤           1        Motel         6220
#
#              LDGS_ROAD_NM_ADDR    LDGS_LA     LDGS_LO CHIN_TIME CHOT_TIME  \
# 0   서울 영등포구 경인로108길 8 (영등포동1가)  37.517182  126.911217     23:00     12:00
# 1  충청북도 청주시 청원구 오창읍 양청송대길 9-12  36.713884  127.439228     18:00     12:00
# 2         서울특별시 강남구 테헤란로16길 11  37.498792  127.033956     23:00     13:00
# 3         대전광역시 유성구 온천북로59번길 9  36.356873  127.349172     17:00     13:00
# 4       서울 강남구 언주로87길 41 (역삼동)  37.500706  127.039849     23:00     12:00
#
#    ...   지역별_관심도 유튜브_상위20_평균조회수 가장 오래된 리뷰_x  error   별점     리뷰수    주중판매가  \
# 0  ...  3.057270         725000  2017.11.16    NaN  4.7   3,202  65000.0
# 1  ...  2.802088          67961  2017.12.02    NaN  4.6     670  55000.0
# 2  ...  3.057270         725000  2017.10.18    NaN  4.2   9,275  60000.0
# 3  ...  2.918471         155050  2017.12.09    NaN  4.7     245  60000.0
# 4  ...  3.057270         725000  2017.10.23    NaN  4.8  10,124  55000.0
#
#       주말판매가 판매가비율  가장 오래된 리뷰_y
# 0  110000.0  1.69   2017.11.16
# 1   50000.0  0.91   2017.12.02
# 2  120000.0  2.00   2017.10.18
# 3   90000.0  1.50   2017.12.09
# 4  125000.0  2.27   2017.10.23
#
# [5 rows x 23 columns]

# %% [markdown]
# ## 컬럼명 정제

# %%
# 가장 오래된 리뷰_x, error 는 삭제
df_merged = df_merged.drop(columns=['가장 오래된 리뷰_x', 'error'])

# %%
# df_merged 컬럼명 변경

# %%
df_merged = df_merged.rename(columns={
    'LDGS_NM': '숙소명',
    'LDGS_TY_CD': '숙소유형코드',
    'LDGMNT_TY_NM': '숙소운영형태',
    'LDGS_ZIP_NO': '우편번호',
    'LDGS_ROAD_NM_ADDR': '도로명주소',
    'LDGS_LA': '위도',
    'LDGS_LO': '경도',
    'CHIN_TIME': '체크인시간',
    'CHOT_TIME': '체크아웃시간'
})

# %%
df_merged = df_merged.rename(columns={'가장 오래된 리뷰_y': '가장 오래된 리뷰'})

# %%
df_merged = df_merged.rename(columns={'가장 오래된 리뷰': '최초리뷰날짜'})

# %%
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20838 entries, 0 to 20837
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   숙소ID            20838 non-null  int64
#  1   숙소명             20838 non-null  object
#  2   숙소유형코드          20838 non-null  int64
#  3   숙소운영형태          20838 non-null  object
#  4   우편번호            20838 non-null  int64
#  5   도로명주소           20838 non-null  object
#  6   위도              20838 non-null  float64
#  7   경도              20838 non-null  float64
#  8   체크인시간           20838 non-null  object
#  9   체크아웃시간          20838 non-null  object
#  10  숙소 검색량(전체)      20838 non-null  object
#  11  상위 시도           20838 non-null  object
#  12  하위 시구           20838 non-null  object
#  13  지역별_관심도         20838 non-null  float64
#  14  유튜브_상위20_평균조회수  20838 non-null  int64
#  15  별점              20838 non-null  float64
#  16  리뷰수             20838 non-null  object
#  17  주중판매가           20838 non-null  float64
#  18  주말판매가           20838 non-null  float64
#  19  판매가비율           20838 non-null  float64
#  20  최초리뷰날짜          20767 non-null  object
# dtypes: float64(7), int64(4), object(10)
# memory usage: 3.3+ MB

# %%
new_order = [
    '숙소ID', '숙소명',
    '숙소유형코드', '숙소운영형태',
    '우편번호', '도로명주소', '위도', '경도',
    '체크인시간', '체크아웃시간',
    '숙소 검색량(전체)', '상위 시도', '하위 시구', '지역별_관심도', '유튜브_상위20_평균조회수',
    '별점', '주중판매가', '주말판매가', '판매가비율',
    '리뷰수', '최초리뷰날짜'
]

df_merged = df_merged[new_order]

# %%
# 최초리뷰날짜 NaN  값인행만 출력
df_merged[df_merged['최초리뷰날짜'].isna()]
# Out:
#              숙소ID            숙소명  숙소유형코드   숙소운영형태   우편번호  \
# 51          23520        수원행궁동르노       1    Motel  16257
# 394         24868    부산사상MU(사상점)       1    Motel  46963
# 865         26275          강남시애틀       1    Motel   6241
# 895         26352        천안캘리포니아       1    Motel  31124
# 1070        26826       보령(대천)발리       1    Motel  33487
# ...           ...            ...     ...      ...    ...
# 18152  1000102548          양주마운틴       1    Motel  11519
# 18706  1000105222          종로아미가       1    Motel   3129
# 18708  1000105240  광주상무벤틀리비즈니스호텔       1    Motel  61964
# 19691  1000110399         종로다나호텔       1    Motel   3192
# 19779  1000110768       양양힐링우드펜션       3  Pension  25051
#
#                                 도로명주소         위도          경도  체크인시간 체크아웃시간  \
# 51          경기도 수원시 팔달구 정조로788번길 11-3  37.278727  127.017221  20:00  11:00
# 394             부산광역시 사상구 사상로211번길 46  35.164110  128.981205  21:00  13:00
# 865            서울 강남구 테헤란로2길 37 (역삼동)  37.495857  127.029985  23:00  12:00
# 895    충청남도 천안시 동남구 신부2길 34 (캘리포니아모텔)  36.818725  127.159925  17:00  14:00
# 1070             충청남도 보령시 해수욕장3길 11-5  36.305521  126.518850  15:00  11:00
# ...                               ...        ...         ...    ...    ...
# 18152      경기도 양주시 장흥면 권율로309번길 67-19  37.741797  126.953108  17:00  12:00
# 18706       서울특별시 종로구 종로31길 46-8(연지동)  37.572668  126.999413  15:00  23:00
# 18708         광주광역시 서구 상무평화로 124(치평동)  35.149047  126.852299  15:00  12:00
# 19691        서울특별시 종로구 수표로18길 10(관수동)  37.569163  126.990120  21:00  12:00
# 19779            강원도 양양군 현북면 어성전길 376  37.932531  128.672311  15:00  11:00
#
#        ... 상위 시도 하위 시구   지역별_관심도  유튜브_상위20_평균조회수   별점     주중판매가     주말판매가  \
# 51     ...    경기   수원시  2.928911          246000  2.0   37000.0   65000.0
# 394    ...    부산   사상구  3.121910          673500  5.0   39000.0   78000.0
# 865    ...    서울   강남구  3.057270          725000  4.8   75000.0  130000.0
# 895    ...    충남   천안시  2.918471          101900  5.0   63000.0  103000.0
# 1070   ...    충남   보령시  2.918471          101900  4.0   42000.0  144000.0
# ...    ...   ...   ...       ...             ...  ...       ...       ...
# 18152  ...    경기   양주시  2.928911          246000  4.9   37000.0   50000.0
# 18706  ...    서울   종로구  3.057270          725000  5.0   69000.0  119000.0
# 18708  ...    광주    서구  2.923691          239400  4.8   55000.0   65000.0
# 19691  ...    서울   종로구  3.057270          725000  4.6   99000.0  489000.0
# 19779  ...    강원   양양군  3.277752          403615  3.0  130000.0  130000.0
#
#        판매가비율  리뷰수 최초리뷰날짜
# 51      1.76    2    NaN
# 394     2.00    8    NaN
# 865     1.73   49    NaN
# 895     1.63    1    NaN
# 1070    3.43    2    NaN
# ...      ...  ...    ...
# 18152   1.35  210    NaN
# 18706   1.72   28    NaN
# 18708   1.18  133    NaN
# 19691   4.94   36    NaN
# 19779   1.00    1    NaN
#
# [71 rows x 21 columns]

# %%
# 최초리뷰날짜 NaN  값인행만 삭제
df_merged = df_merged.dropna(subset=['최초리뷰날짜'])

# %%
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20767 entries, 0 to 20837
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   숙소ID            20767 non-null  int64
#  1   숙소명             20767 non-null  object
#  2   숙소유형코드          20767 non-null  int64
#  3   숙소운영형태          20767 non-null  object
#  4   우편번호            20767 non-null  int64
#  5   도로명주소           20767 non-null  object
#  6   위도              20767 non-null  float64
#  7   경도              20767 non-null  float64
#  8   체크인시간           20767 non-null  object
#  9   체크아웃시간          20767 non-null  object
#  10  숙소 검색량(전체)      20767 non-null  object
#  11  상위 시도           20767 non-null  object
#  12  하위 시구           20767 non-null  object
#  13  지역별_관심도         20767 non-null  float64
#  14  유튜브_상위20_평균조회수  20767 non-null  int64
#  15  별점              20767 non-null  float64
#  16  주중판매가           20767 non-null  float64
#  17  주말판매가           20767 non-null  float64
#  18  판매가비율           20767 non-null  float64
#  19  리뷰수             20767 non-null  object
#  20  최초리뷰날짜          20767 non-null  object
# dtypes: float64(7), int64(4), object(10)
# memory usage: 3.5+ MB

# %%
df_최종프레임0811 = df_merged.copy()

# %%
df_최종프레임0811.to_csv('08011_메인프레임v9.csv', index=False)

# %%
df_최종프레임0811
# Out:
#              숙소ID                  숙소명  숙소유형코드 숙소운영형태   우편번호  \
# 0           23184      영등포라이프스타일FHOTEL       1  Motel   7306
# 1           23192               청주오창M+       1  Motel  28118
# 2           23197                 강남렉시       1  Motel   6235
# 3           23204             대전유성시나브로       1  Motel  34185
# 4           23207                  역삼벤       1  Motel   6220
# ...           ...                  ...     ...    ...    ...
# 20833  1000114526             전주중노송동파인       1  Motel  55000
# 20834  1000114529        거창서핑파크리조트&글램핑       2  Hotel  50103
# 20835  1000114558                 여수굿썸       1  Motel  59769
# 20836  1000114577          순천브라운도트순천역점       1  Motel  57964
# 20837  1000114675  인천(검단)브라운도트인천검단사거리점       1  Motel  22636
#
#                              도로명주소         위도          경도  체크인시간 체크아웃시간  ...  \
# 0       서울 영등포구 경인로108길 8 (영등포동1가)  37.517182  126.911217  23:00  12:00  ...
# 1      충청북도 청주시 청원구 오창읍 양청송대길 9-12  36.713884  127.439228  18:00  12:00  ...
# 2             서울특별시 강남구 테헤란로16길 11  37.498792  127.033956  23:00  13:00  ...
# 3             대전광역시 유성구 온천북로59번길 9  36.356873  127.349172  17:00  13:00  ...
# 4           서울 강남구 언주로87길 41 (역삼동)  37.500706  127.039849  23:00  12:00  ...
# ...                            ...        ...         ...    ...    ...  ...
# 20833         전라북도 전주시 완산구 현무3길 54  35.822097  127.150451  16:00  12:00  ...
# 20834      경상남도 거창군 위천면 거차1길 23-18  35.747967  127.836350  15:00  11:00  ...
# 20835          전라남도 여수시 돌산읍 강남로 45  34.719781  127.750254  15:00  11:00  ...
# 20836             전라남도 순천시 팔마로 153  34.944613  127.504991  23:00  11:00  ...
# 20837    인천광역시 서구 완정로117번길 31(왕길동)  37.600624  126.659497  22:00  12:00  ...
#
#       상위 시도 하위 시구   지역별_관심도  유튜브_상위20_평균조회수   별점     주중판매가     주말판매가  판매가비율  \
# 0        서울  영등포구  3.057270          725000  4.7   65000.0  110000.0   1.69
# 1        충북   청주시  2.802088           67961  4.6   55000.0   50000.0   0.91
# 2        서울   강남구  3.057270          725000  4.2   60000.0  120000.0   2.00
# 3        대전   유성구  2.918471          155050  4.7   60000.0   90000.0   1.50
# 4        서울   강남구  3.057270          725000  4.8   55000.0  125000.0   2.27
# ...     ...   ...       ...             ...  ...       ...       ...    ...
# 20833    전북   전주시  2.833871          120072  3.3   45000.0   60000.0   1.33
# 20834    경남   거창군  2.794718          131945  4.3  115000.0  140000.0   1.22
# 20835    전남   여수시  2.923691           70700  2.7   60000.0   80000.0   1.33
# 20836    전남   순천시  2.923691           70700  4.9   70000.0  100000.0   1.43
# 20837    인천    서구  2.928911          264000  4.9   55000.0   80000.0   1.45
#
#           리뷰수      최초리뷰날짜
# 0       3,202  2017.11.16
# 1         670  2017.12.02
# 2       9,275  2017.10.18
# 3         245  2017.12.09
# 4      10,124  2017.10.23
# ...       ...         ...
# 20833      64  2021.06.18
# 20834      51  2021.10.10
# 20835      38  2021.06.07
# 20836     456  2021.10.03
# 20837   1,168  2021.09.29
#
# [20767 rows x 21 columns]

# %% [markdown]
# # 별점 정제

# %%
import pandas as pd
df_main = pd.read_csv("프로젝트/0811_메인프레임v9.csv")
df_main.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20767 entries, 0 to 20766
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   숙소ID            20767 non-null  int64
#  1   숙소명             20767 non-null  object
#  2   숙소유형코드          20767 non-null  int64
#  3   숙소운영형태          20767 non-null  object
#  4   우편번호            20767 non-null  int64
#  5   도로명주소           20767 non-null  object
#  6   위도              20767 non-null  float64
#  7   경도              20767 non-null  float64
#  8   체크인시간           20767 non-null  object
#  9   체크아웃시간          20767 non-null  object
#  10  숙소 검색량(전체)      20767 non-null  object
#  11  상위 시도           20767 non-null  object
#  12  하위 시구           20767 non-null  object
#  13  지역별_관심도         20767 non-null  float64
#  14  유튜브_상위20_평균조회수  20767 non-null  int64
#  15  별점              20767 non-null  float64
#  16  주중판매가           20767 non-null  float64
#  17  주말판매가           20767 non-null  float64
#  18  판매가비율           20767 non-null  float64
#  19  리뷰수             20767 non-null  object
#  20  최초리뷰날짜          20767 non-null  object
# dtypes: float64(7), int64(4), object(10)
# memory usage: 3.3+ MB

# %%
df_main['별점'].value_counts()
# Out:
# 별점
# 5.0      4962
# 4.8      2909
# 4.7      2306
# 4.9      2004
# 4.6      1733
# 4.5      1552
# 4.4       913
# 4.0       912
# 4.3       912
# 4.2       418
# 3.0       358
# 4.1       305
# 3.7       208
# 1.0       205
# 3.8       194
# 3.5       149
# 3.9       134
# 2.0       113
# 3.3       102
# 3.6        83
# 3.4        63
# 3.2        38
# 2.5        35
# 2.8        26
# 2.3        25
# 2.7        23
# 3.1        21
# 1.5        14
# 2.6        13
# 2.9         9
# 2.2         6
# 1.7         6
# 1.8         5
# 2.4         4
# 1.3         3
# 1.2         2
# 262.0       1
# 2.1         1
# Name: count, dtype: int64

# %%
# 별점이 262인 데이터 4.8로 변경
df_main.loc[df_main['별점'] == 262.0, '별점'] = 4.8

# %%
df_main['별점'].value_counts()
# Out:
# 별점
# 5.0    4962
# 4.8    2910
# 4.7    2306
# 4.9    2004
# 4.6    1733
# 4.5    1552
# 4.4     913
# 4.3     912
# 4.0     912
# 4.2     418
# 3.0     358
# 4.1     305
# 3.7     208
# 1.0     205
# 3.8     194
# 3.5     149
# 3.9     134
# 2.0     113
# 3.3     102
# 3.6      83
# 3.4      63
# 3.2      38
# 2.5      35
# 2.8      26
# 2.3      25
# 2.7      23
# 3.1      21
# 1.5      14
# 2.6      13
# 2.9       9
# 1.7       6
# 2.2       6
# 1.8       5
# 2.4       4
# 1.3       3
# 1.2       2
# 2.1       1
# Name: count, dtype: int64

# %%
df_main.to_csv("프로젝트/0811_메인프레임v10.csv", index=False)

# %% [markdown]
# # 주말 판매가 오류인 행 수정

# %%
import pandas as pd
df_주말판매가오류 = pd.read_csv('프로젝트/0814_메인프레임v12.csv')

# %%
df_주말판매가오류.describe()
# Out:
#                숙소ID        숙소유형코드          우편번호            위도            경도  \
# count  2.076600e+04  20766.000000  20766.000000  20766.000000  20766.000000
# mean   1.924532e+08      2.073004  35315.456082     36.302376    127.710135
# std    3.879717e+08      0.967453  17591.409452      1.323664      0.987622
# min    2.318400e+04      1.000000      0.000000     33.209238    124.708279
# 25%    3.009493e+06      1.000000  23059.000000     35.205084    126.883883
# 50%    1.004515e+07      2.000000  33489.000000     36.450288    127.503004
# 75%    1.005826e+07      3.000000  52402.000000     37.515297    128.622748
# max    1.000115e+09      4.000000  63643.000000     38.537820    130.912016
#
#             지역별_관심도  지역별_유튜브Top20_평균조회수            별점         주중판매가  \
# count  20766.000000        2.076600e+04  20766.000000  2.076600e+04
# mean       2.947838        3.692132e+05      4.549894  1.121020e+05
# std        0.168887        3.827523e+05      0.616131  1.111334e+05
# min        2.700599        4.966000e+04      1.000000  8.000000e+03
# 25%        2.802088        1.319450e+05      4.400000  5.000000e+04
# 50%        2.928911        2.460000e+05      4.700000  7.500000e+04
# 75%        3.062183        4.036150e+05      4.900000  1.300000e+05
# max        3.277752        1.606000e+06      5.000000  2.000000e+06
#
#               주말판매가         판매가비율
# count  2.076600e+04  20766.000000
# mean   1.725632e+05      1.616272
# std    1.631467e+05      0.657363
# min    8.000000e+03      0.200000
# 25%    7.000000e+04      1.200000
# 50%    1.200000e+05      1.500000
# 75%    2.100000e+05      1.900000
# max    2.100000e+06     12.500000

# %%
df_주말판매가오류[df_주말판매가오류['판매가비율'] < 1]
# Out:
#              숙소ID             숙소명  숙소유형코드   숙소운영형태   우편번호  \
# 1           23192          청주오창M+       1    Motel  28118
# 24          23279        홍천WHouse       1    Motel  25117
# 339         24703      안동윈(WIN)호텔       1    Motel  36657
# 389         24853  창원상남동뷰티크호텔궁(宮)       1    Motel  51496
# 450         25073           부산초읍루       1    Motel  47124
# ...           ...             ...     ...      ...    ...
# 20577  1000113721        제주월정가옥펜션       3  Pension  63358
# 20670  1000114028         제주벨룸리조트       2    Hotel  63580
# 20672  1000114042       여수48시간풀빌라       3  Pension  59782
# 20716  1000114223     태안(안면도)구름펜션       3  Pension  32166
# 20759  1000114523      광양늘드라이브인호텔       2    Hotel  57760
#
#                              도로명주소         위도          경도  체크인시간 체크아웃시간  ...  \
# 1      충청북도 청주시 청원구 오창읍 양청송대길 9-12  36.713884  127.439228  18:00  12:00  ...
# 24            강원도 홍천군 홍천읍 설악로 1471  37.680725  127.864806  17:00  12:00  ...
# 339                경상북도 안동시 옥명길 28  36.564481  128.702504  17:00  12:00  ...
# 389        경상남도 창원시 성산구 마디미로44번길 7  35.220915  128.682474  17:00  12:00  ...
# 450          부산광역시 부산진구 성지로153번길 9  35.181472  129.048054  18:00  12:00  ...
# ...                            ...        ...         ...    ...    ...  ...
# 20577    제주시 구좌읍 월정중길 39 (월정리)월정가옥  33.558572  126.792632  16:00  10:00  ...
# 20670    제주특별자치도 서귀포시 516로277번길 45  33.279360  126.581433  15:00  11:00  ...
# 20672     전라남도 여수시 화정면 백야등대길 22 2층  34.609997  127.651306  15:00  11:00  ...
# 20716        충청남도 태안군 안면읍 꽃지1길 142  36.499765  126.342443  15:00  11:00  ...
# 20759         전라남도 광양시 광양읍 덕산1길 27  34.967429  127.565171  18:00  12:00  ...
#
#       상위 시도 하위 시구   지역별_관심도  지역별_유튜브Top20_평균조회수   별점   주중판매가   주말판매가  판매가비율  \
# 1        충북   청주시  2.802088               67961  4.6   55000   50000    0.9
# 24       강원   홍천군  3.277752              403615  4.0   60000   50000    0.8
# 339      경북   안동시  2.700599              321600  4.7  100000   80000    0.8
# 389      경남   창원시  2.794718              131945  4.7   45000   42500    0.9
# 450      부산  부산진구  3.121910              673500  4.6   40000   35000    0.9
# ...     ...   ...       ...                 ...  ...     ...     ...    ...
# 20577    제주   구좌읍  3.062183             1606000  4.6  160000  130000    0.8
# 20670    제주  서귀포시  3.062183             1606000  4.2  340000  270000    0.8
# 20672    전남   여수시  2.923691               70700  5.0  776000  310000    0.4
# 20716    충남   태안군  2.918471              101900  5.0  130000  120000    0.9
# 20759    전남   광양시  2.923691               70700  3.7   90000   80000    0.9
#
#          리뷰수      최초리뷰날짜
# 1        670  2017.12.02
# 24         9  2024.09.15
# 339      487  2023.12.26
# 389    3,844  2024.12.25
# 450      504  2018.01.20
# ...      ...         ...
# 20577     62  2021.06.02
# 20670     62  2022.06.14
# 20672      9  2024.08.03
# 20716     32  2021.07.01
# 20759     27  2021.12.18
#
# [469 rows x 21 columns]

# %%
# 판매가비율 1 보다 작은 행출력
df_주말판매가오류[df_주말판매가오류['판매가비율'] < 1].to_csv('0814_판매가비율1미만.csv', index=False)

# %% [markdown]
# ## 판매비율 문제 및 주말 판매가오류 수정

# %%
df_판매비율오류 = pd.read_csv("프로젝트/0814야놀자_주말판매가크롤링.csv")

# %%
df_판매비율오류
# Out:
#            숙소ID       주말판매가
# 0       1016034    130,000원
# 1       3000435     80,000원
# 2       3000742    216,810원
# 3       3000750    415,000원
# 4       3000769    338,580원
# ..          ...         ...
# 221  1000113721    160,000원
# 222  1000114028    340,000원
# 223  1000114042  1,000,000원
# 224  1000114223    360,000원
# 225  1000114523     80,000원
#
# [226 rows x 2 columns]

# %%
# 주말 판매가 정보없음 출력
df_판매비율오류[df_판매비율오류["주말판매가"] == '정보 없음']
# Out:
#        숙소ID  주말판매가
# 65  3017757  정보 없음

# %%
# 3017757  가격 변경
df_판매비율오류.loc[df_판매비율오류["숙소ID"] == 3017757, "주말판매가"] = '135,000원'

# %%
# 주말판매가 컬럼  , 과 원은 제거
df_판매비율오류["주말판매가"] = df_판매비율오류["주말판매가"].str.replace("원", "").str.replace(",", "").astype(int)

# %%
df_판매비율오류.to_csv("프로젝트/0814야놀자_주말판매가크롤링_v2.csv", index=False)

# %% [markdown]
# # 리뷰 감성 점수 매핑 및 파생변수 생성

# %%
import pandas as pd
df_v10 = pd.read_csv('프로젝트/0811_메인프레임v10.csv')
df_감성별점 = pd.read_csv('프로젝트/숙소별_감성별점_평균.csv')

# %%
df_감성별점.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19510 entries, 0 to 19509
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   숙소ID    19510 non-null  int64
#  1   감성별점    19510 non-null  float64
# dtypes: float64(1), int64(1)
# memory usage: 305.0 KB

# %%
# df_감성별점 과 df_v10  숙소ID 기준으로 감성별점 컬럼 병합  만약 숙소ID가 일치하지 않으면 NaN으로 채우기
df_감성별점추가 = df_v10.merge(df_감성별점[['숙소ID', '감성별점']], on='숙소ID', how='left')

# %%
df_감성별점추가.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20767 entries, 0 to 20766
# Data columns (total 22 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   숙소ID            20767 non-null  int64
#  1   숙소명             20767 non-null  object
#  2   숙소유형코드          20767 non-null  int64
#  3   숙소운영형태          20767 non-null  object
#  4   우편번호            20767 non-null  int64
#  5   도로명주소           20767 non-null  object
#  6   위도              20767 non-null  float64
#  7   경도              20767 non-null  float64
#  8   체크인시간           20767 non-null  object
#  9   체크아웃시간          20767 non-null  object
#  10  숙소 검색량(전체)      20767 non-null  object
#  11  상위 시도           20767 non-null  object
#  12  하위 시구           20767 non-null  object
#  13  지역별_관심도         20767 non-null  float64
#  14  유튜브_상위20_평균조회수  20767 non-null  int64
#  15  별점              20767 non-null  float64
#  16  주중판매가           20767 non-null  float64
#  17  주말판매가           20767 non-null  float64
#  18  판매가비율           20767 non-null  float64
#  19  리뷰수             20767 non-null  object
#  20  최초리뷰날짜          20767 non-null  object
#  21  감성별점            19405 non-null  float64
# dtypes: float64(8), int64(4), object(10)
# memory usage: 3.5+ MB

# %%
df_감성별점추가.head()
# Out:
#     숙소ID              숙소명  숙소유형코드 숙소운영형태   우편번호                        도로명주소  \
# 0  23184  영등포라이프스타일FHOTEL       1  Motel   7306   서울 영등포구 경인로108길 8 (영등포동1가)
# 1  23192           청주오창M+       1  Motel  28118  충청북도 청주시 청원구 오창읍 양청송대길 9-12
# 2  23197             강남렉시       1  Motel   6235         서울특별시 강남구 테헤란로16길 11
# 3  23204         대전유성시나브로       1  Motel  34185         대전광역시 유성구 온천북로59번길 9
# 4  23207              역삼벤       1  Motel   6220       서울 강남구 언주로87길 41 (역삼동)
#
#           위도          경도  체크인시간 체크아웃시간  ... 하위 시구   지역별_관심도 유튜브_상위20_평균조회수  \
# 0  37.517182  126.911217  23:00  12:00  ...  영등포구  3.057270         725000
# 1  36.713884  127.439228  18:00  12:00  ...   청주시  2.802088          67961
# 2  37.498792  127.033956  23:00  13:00  ...   강남구  3.057270         725000
# 3  36.356873  127.349172  17:00  13:00  ...   유성구  2.918471         155050
# 4  37.500706  127.039849  23:00  12:00  ...   강남구  3.057270         725000
#
#     별점    주중판매가     주말판매가  판매가비율     리뷰수      최초리뷰날짜      감성별점
# 0  4.7  65000.0  110000.0   1.69   3,202  2017.11.16  3.100239
# 1  4.6  55000.0   50000.0   0.91     670  2017.12.02  3.751613
# 2  4.2  60000.0  120000.0   2.00   9,275  2017.10.18  2.858000
# 3  4.7  60000.0   90000.0   1.50     245  2017.12.09  4.112426
# 4  4.8  55000.0  125000.0   2.27  10,124  2017.10.23  2.979960
#
# [5 rows x 22 columns]

# %%
# 종합평균점수를 소수점 첫째 자리까지  반올림
df_감성별점추가['종합평균점수'] = (
    (df_감성별점추가['별점'] + df_감성별점추가['감성별점']) / 2
).round(1)

# 확인
df_감성별점추가[['별점', '감성별점', '종합평균점수']].head()
# Out:
#     별점      감성별점  종합평균점수
# 0  4.7  3.100239     3.9
# 1  4.6  3.751613     4.2
# 2  4.2  2.858000     3.5
# 3  4.7  4.112426     4.4
# 4  4.8  2.979960     3.9

# %%
# 감성별점 소수점 첫째 자리까지 반올림
df_감성별점추가['감성별점'] = df_감성별점추가['감성별점'].round(1)

# 확인
df_감성별점추가[['감성별점']].head()
# Out:
#    감성별점
# 0   3.1
# 1   3.8
# 2   2.9
# 3   4.1
# 4   3.0

# %%
df_감성별점추가.head()
# Out:
#     숙소ID              숙소명  숙소유형코드 숙소운영형태   우편번호                        도로명주소  \
# 0  23184  영등포라이프스타일FHOTEL       1  Motel   7306   서울 영등포구 경인로108길 8 (영등포동1가)
# 1  23192           청주오창M+       1  Motel  28118  충청북도 청주시 청원구 오창읍 양청송대길 9-12
# 2  23197             강남렉시       1  Motel   6235         서울특별시 강남구 테헤란로16길 11
# 3  23204         대전유성시나브로       1  Motel  34185         대전광역시 유성구 온천북로59번길 9
# 4  23207              역삼벤       1  Motel   6220       서울 강남구 언주로87길 41 (역삼동)
#
#           위도          경도  체크인시간 체크아웃시간  ...   지역별_관심도 유튜브_상위20_평균조회수   별점  \
# 0  37.517182  126.911217  23:00  12:00  ...  3.057270         725000  4.7
# 1  36.713884  127.439228  18:00  12:00  ...  2.802088          67961  4.6
# 2  37.498792  127.033956  23:00  13:00  ...  3.057270         725000  4.2
# 3  36.356873  127.349172  17:00  13:00  ...  2.918471         155050  4.7
# 4  37.500706  127.039849  23:00  12:00  ...  3.057270         725000  4.8
#
#      주중판매가     주말판매가  판매가비율     리뷰수      최초리뷰날짜  감성별점 종합평균점수
# 0  65000.0  110000.0   1.69   3,202  2017.11.16   3.1    3.9
# 1  55000.0   50000.0   0.91     670  2017.12.02   3.8    4.2
# 2  60000.0  120000.0   2.00   9,275  2017.10.18   2.9    3.5
# 3  60000.0   90000.0   1.50     245  2017.12.09   4.1    4.4
# 4  55000.0  125000.0   2.27  10,124  2017.10.23   3.0    3.9
#
# [5 rows x 23 columns]

# %%
# 컬럼명 변경
df_감성별점추가.rename(columns={'최초리뷰날짜': '최초리뷰일자'}, inplace=True)

# 날짜 컬럼을 datetime 형식으로 변환
df_감성별점추가['최초리뷰일자'] = pd.to_datetime(df_감성별점추가['최초리뷰일자'])

# 연, 월 컬럼 생성
df_감성별점추가['리뷰연도'] = df_감성별점추가['최초리뷰일자'].dt.year
df_감성별점추가['리뷰월'] = df_감성별점추가['최초리뷰일자'].dt.month

# %%
df_감성별점추가
# Out:
#              숙소ID                  숙소명  숙소유형코드 숙소운영형태   우편번호  \
# 0           23184      영등포라이프스타일FHOTEL       1  Motel   7306
# 1           23192               청주오창M+       1  Motel  28118
# 2           23197                 강남렉시       1  Motel   6235
# 3           23204             대전유성시나브로       1  Motel  34185
# 4           23207                  역삼벤       1  Motel   6220
# ...           ...                  ...     ...    ...    ...
# 20762  1000114526             전주중노송동파인       1  Motel  55000
# 20763  1000114529        거창서핑파크리조트&글램핑       2  Hotel  50103
# 20764  1000114558                 여수굿썸       1  Motel  59769
# 20765  1000114577          순천브라운도트순천역점       1  Motel  57964
# 20766  1000114675  인천(검단)브라운도트인천검단사거리점       1  Motel  22636
#
#                              도로명주소         위도          경도  체크인시간 체크아웃시간  ...  \
# 0       서울 영등포구 경인로108길 8 (영등포동1가)  37.517182  126.911217  23:00  12:00  ...
# 1      충청북도 청주시 청원구 오창읍 양청송대길 9-12  36.713884  127.439228  18:00  12:00  ...
# 2             서울특별시 강남구 테헤란로16길 11  37.498792  127.033956  23:00  13:00  ...
# 3             대전광역시 유성구 온천북로59번길 9  36.356873  127.349172  17:00  13:00  ...
# 4           서울 강남구 언주로87길 41 (역삼동)  37.500706  127.039849  23:00  12:00  ...
# ...                            ...        ...         ...    ...    ...  ...
# 20762         전라북도 전주시 완산구 현무3길 54  35.822097  127.150451  16:00  12:00  ...
# 20763      경상남도 거창군 위천면 거차1길 23-18  35.747967  127.836350  15:00  11:00  ...
# 20764          전라남도 여수시 돌산읍 강남로 45  34.719781  127.750254  15:00  11:00  ...
# 20765             전라남도 순천시 팔마로 153  34.944613  127.504991  23:00  11:00  ...
# 20766    인천광역시 서구 완정로117번길 31(왕길동)  37.600624  126.659497  22:00  12:00  ...
#
#         별점     주중판매가     주말판매가  판매가비율     리뷰수     최초리뷰일자  감성별점  종합평균점수  리뷰연도  \
# 0      4.7   65000.0  110000.0   1.69   3,202 2017-11-16   3.1     3.9  2017
# 1      4.6   55000.0   50000.0   0.91     670 2017-12-02   3.8     4.2  2017
# 2      4.2   60000.0  120000.0   2.00   9,275 2017-10-18   2.9     3.5  2017
# 3      4.7   60000.0   90000.0   1.50     245 2017-12-09   4.1     4.4  2017
# 4      4.8   55000.0  125000.0   2.27  10,124 2017-10-23   3.0     3.9  2017
# ...    ...       ...       ...    ...     ...        ...   ...     ...   ...
# 20762  3.3   45000.0   60000.0   1.33      64 2021-06-18   4.4     3.9  2021
# 20763  4.3  115000.0  140000.0   1.22      51 2021-10-10   3.5     3.9  2021
# 20764  2.7   60000.0   80000.0   1.33      38 2021-06-07   4.2     3.5  2021
# 20765  4.9   70000.0  100000.0   1.43     456 2021-10-03   4.2     4.6  2021
# 20766  4.9   55000.0   80000.0   1.45   1,168 2021-09-29   3.9     4.4  2021
#
#       리뷰월
# 0      11
# 1      12
# 2      10
# 3      12
# 4      10
# ...    ..
# 20762   6
# 20763  10
# 20764   6
# 20765  10
# 20766   9
#
# [20767 rows x 25 columns]

# %%
# 컬럼명 변경
df_감성별점추가.rename(columns={
    '리뷰연도': '최초리뷰연도',
    '리뷰월': '최초리뷰월'
}, inplace=True)

# %%
df_감성별점추가.to_csv('프로젝트/0811_메인프레임v10_감성별점추가.csv', index=False)

# %% [markdown]
# # 야놀자 이미지url 정제 및 매핑

# %%
import pandas as pd

df_이미지 = pd.read_csv('YN_LDGS_PROPRERTY_PHOTO_URL_202412.csv')
df_main = pd.read_csv('프로젝트/0812_메인프레임v11.csv')

# %%
df_이미지

# %%
# LDGS_CD, GSRM_IMAGE_URL 컬럼명 변경
df_이미지.rename(columns={'LDGS_CD': '숙소ID', 'GSRM_IMAGE_URL': '이미지URL'}, inplace=True)

# %%
# 이미지URL 중복 확인
duplicate_image = df_이미지[df_이미지.duplicated(['이미지URL'], keep=False)]

# %%
duplicate_image

# %%
import pandas as pd

# 1) 기본 정리: 결측/공백 제거, (숙소ID, 이미지URL) 중복 제거
df1 = (
    df_이미지.copy()
      .dropna(subset=['숙소ID', '이미지URL'])
)
df1['이미지URL'] = df1['이미지URL'].astype(str).str.strip()
df1 = df1.drop_duplicates(subset=['숙소ID', '이미지URL'])

# 2) 날짜 파싱 (있으면 최신 우선)
if 'IMAGE_RNEWL_DE' in df1.columns:
    df1['IMAGE_RNEWL_DE'] = pd.to_datetime(df1['IMAGE_RNEWL_DE'], errors='coerce')
else:
    df1['IMAGE_RNEWL_DE'] = pd.NaT

# 3) 숙소ID별 최신순 정렬 후 최대 3개 선택
df_top3 = (
    df1.sort_values(['숙소ID', 'IMAGE_RNEWL_DE'], ascending=[True, False])
       .groupby('숙소ID', as_index=False)
       .head(3)
       .reset_index(drop=True)
)

# 4) 필요한 컬럼만 남기기
df_이미지_top3_long = df_top3[['숙소ID', '이미지URL']]

# 결과 예시
print(df_이미지_top3_long.head())

# %%
df_이미지_top3_long

# %%
df_main.head()

# %%
# df_main과 df_이미지_top3_long 모두 '숙소ID'가 같은 타입(str/int)인지 확인
df_main['숙소ID'] = df_main['숙소ID'].astype(str)
df_이미지_top3_long['숙소ID'] = df_이미지_top3_long['숙소ID'].astype(str)

# df_main에 있는 숙소ID만 필터링
df_이미지_top3_long = df_이미지_top3_long[
    df_이미지_top3_long['숙소ID'].isin(df_main['숙소ID'])
].reset_index(drop=True)

# %%
df_이미지_top3_long.to_csv('이미지URL_최신3개.csv', index=False)
